# %%
cd /root/notebooks
# Out:
# /root/notebooks

# %%
rm -rf resultados-31-01/

# %%
ls
# Out:
# DATABASE-PRIVATE/                 datos-SSH-Keys.ipynb   script.sh
# Datos_Combarbala_2016-2017JM.csv  Gif-Rocio-Combarbala/
# datos.csv                         requirements.txt

# %%
pwd
# Out:
# '/root/notebooks'

# %%
pwd
# Out:
# '/root/notebooks'

# %%
#!git clone git@github.com:Rodrigomontenegrofarias/resultados-31-01.git
# Out:
# Cloning into 'resultados-31-01'...
# remote: Enumerating objects: 716, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 716 (delta 91), reused 113 (delta 69), pack-reused 581
# Receiving objects: 100% (716/716), 115.42 MiB | 10.78 MiB/s, done.
# Resolving deltas: 100% (487/487), done.

# %%
pwd
# Out:
# '/root/notebooks'

# %%
cd resultados-31-01
# Out:
# /root/notebooks/resultados-31-01

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
cd prueba
# Out:
# /root/notebooks/resultados-31-01/prueba

# %%
cd ..

# %%
pwd
# Out:
# '/root/notebooks/resultados-31-01/prueba'

# %%
mkdir /resultados

# %%
ls -la
# Out:
# total 9712
# drwxr-xr-x 3 root root    4096 Aug 11 16:55 ./
# drwxr-xr-x 4 root root    4096 Aug 11 16:55 ../
# -rw-r--r-- 1 root root 9916366 Aug 11 16:55 exp_final_1.0.ipynb
# -rw-r--r-- 1 root root   15359 Aug 11 16:55 guardar-modelos-ejecutados.ipynb
# drwxr-xr-x 2 root root    4096 Aug 11 16:55 .ipynb_checkpoints/

# %%
cp -r /root/notebooks/resultados-31-01/prueba/exp_final_1.0.ipynb  /root/notebooks/resultados-31-01/resultados

# %%
#cp -r /root/notebooks/exp-7.ipynb  /root/notebooks/result/prueba

# %%
cp -r /root/notebooks/resultados-31-01/prueba/exp_final_1.0.ipynb  /root/notebooks/resultados-31-01/resultados

# %%
#cp -r /root/notebooks/exp-8.ipynb  /root/notebooks/result/prueba

# %%
#cp -r /root/notebooks/exp-9.ipynb  /root/notebooks/result/prueba

# %%
#cp -r /root/notebooks/exp-10.ipynb  /root/notebooks/result/prueba

# %%
cd

# %%
ls

# %%
# !git add .

# %%
# !git config user.email "rodrigo.montenegro@alumnos.uv.cl"

# !git config user.name "Rodrigomontenegrofarias"

# %% [markdown]
# #####

# %%
# !git commit -m 'commit message'  # commit in Colab

# %%
# !git push origin main       # push to github
