# %%
cd /root/notebooks
# Out:
# /root/notebooks

# %%
# !rm -rf resultados-31-01

# %%
# !git clone git@github.com:Rodrigomontenegrofarias/resultados-31-01.git
# Out:
# Cloning into 'resultados-31-01'...
# remote: Enumerating objects: 979, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 979 (delta 34), reused 36 (delta 15), pack-reused 923
# Receiving objects: 100% (979/979), 154.38 MiB | 19.21 MiB/s, done.
# Resolving deltas: 100% (667/667), done.

# %%
cd resultados-31-01/
# Out:
# /root/notebooks/resultados-31-01

# %%
#cargamos librerias
import pandas as pd
import numpy as np
#graficas
import matplotlib.pylab as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,9)
plt.style.use('fast')
#ver redes neuronales

#sklear para ver modelos machine learning
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

import matplotlib.pyplot as plt
# plt.xkcd()
# plt.style.use('ggplot')
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (20, 8)

# %% [markdown]
# # Ingreso de bases de datos y coneccion a drive.

# %%
# !git config user.email "rodrigo.montenegro@alumnos.uv.cl"

# !git config user.name "Rodrigomontenegrofarias"

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
# solo el primer se encuentra en kl/h se debe cambiar a m/S

##Imprlementar desde github:

datos1=pd.read_csv('Prueba1.0.csv',decimal=",", encoding='utf-8',sep=u',')
datos2=pd.read_csv('Prueba2.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos3=pd.read_csv('Prueba3.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos4=pd.read_csv('Prueba4.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos5=pd.read_csv('Prueba5.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos6=pd.read_csv('Prueba6.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos7=pd.read_csv('Prueba7.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
datos8=pd.read_csv('Prueba8.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos9=pd.read_csv('Prueba9.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos10=pd.read_csv('Prueba10.0.csv',decimal=",",sep=u',', encoding='utf-8',dayfirst=True)

#datos11=pd.read_csv('/content/Rodrigomontenegrofarias/resultados/Prueba11.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos12=pd.read_csv('/content/Rodrigomontenegrofarias/resultados/Prueba12.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#datos13=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba13.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos14=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba14.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos15=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba15.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos16=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba16.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos17=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba17.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos18=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba18.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#datos19=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba19.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos20=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba20.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#Fecha
#datos1 = datos1.rename(columns={'Gust(km/h)':'Gust(m/s)'})
#datos1 = datos1.rename(columns={'Wind Speed(km/h)':'Wind Speed(m/s)'})


#df.columns
#Gust(km/h)
 
datos1
# Out:
#    Unnamed: 0 Pruebas      coef(a)_6am-MLP    rsquared_6am-MLP  \
# 0           0     1.0  0.36490655124903987  0.3897614421175062
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0   0.041338251855687624  0.017609918690071016  0.9899460704564589
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP coef(b)_Acu-6am-MLP  ...  \
# 0   0.9667606342674128       0.016618755823697835  0.3575594820816234  ...
#
#   Standard Error_Acu-Pd-MLP-LM coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0         0.005334882577522506     0.076973263889796  0.35808074465091444
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.49951206206154164       0.03245076182211084  0.015182437998358932
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8598239688803573      0.9714045972809758
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0          0.013356038569556618     0.3377343861206118
#
# [1 rows x 50 columns]

# %%
print(datos1)
# Out:
#    Unnamed: 0 Pruebas      coef(a)_6am-MLP    rsquared_6am-MLP  \
# 0           0     1.0  0.36490655124903987  0.3897614421175062
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0   0.041338251855687624  0.017609918690071016  0.9899460704564589
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP coef(b)_Acu-6am-MLP  ...  \
# 0   0.9667606342674128       0.016618755823697835  0.3575594820816234  ...
#
#   Standard Error_Acu-Pd-MLP-LM coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0         0.005334882577522506     0.076973263889796  0.35808074465091444
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.49951206206154164       0.03245076182211084  0.015182437998358932
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8598239688803573      0.9714045972809758
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0          0.013356038569556618     0.3377343861206118
#
# [1 rows x 50 columns]

# %%
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,]
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
resultadoDatos= pd.concat(datostotal)

# %%
resultadoDatos
# Out:
#    Unnamed: 0 Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP  \
# 0           0     1.0  0.36490655124903987   0.3897614421175062
# 0           0     2.0   0.5134709035385809   0.4151113004995016
# 0           0     3.0   0.6029450222655992   0.4552307239383474
# 0           0     4.0  0.43928274718711874   0.2926406794018279
# 0           0     5.0   0.3304023214292526   0.3752359152166953
# 0           0     6.0  0.41213647488729405    0.446190741652399
# 0           0     7.0   0.6475989799535233   0.5275131757258892
# 0           0     8.0  0.46181148587782683   0.3747603497558605
# 0           0     9.0  0.24312817769474987  0.28307739026682743
# 0           0    10.0  0.48252515948573493  0.38573278451744275
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0   0.041338251855687624  0.017609918690071016  0.9899460704564589
# 0    0.05518108544668105  0.018376335113421054  1.1975262733420031
# 0    0.05971567442715505  0.022844419255337804   1.392693978281973
# 0    0.06183251242073693  0.024970838574049574  1.3427081738814446
# 0   0.038598372043825435  0.018862290456259048  0.9931037385436089
# 0    0.04157008861009052  0.017723405599392623  0.9588549963315194
# 0    0.05548868554758156  0.015707933646817114  1.1771915503815036
# 0    0.05400465909998044  0.019195509821561846  1.2937823208009172
# 0    0.03502990261711806  0.014876213546214878  0.6453799132251243
# 0    0.05512840650241081  0.020260452884830832  1.3409167119734908
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP   coef(b)_Acu-6am-MLP  ...  \
# 0   0.9667606342674128       0.016618755823697835    0.3575594820816234  ...
# 0   0.9729030893385013        0.01809381868621007   0.12334575927979059  ...
# 0   0.9545593206802264       0.027510388880073126  -0.12446739661299758  ...
# 0   0.9870973712846349       0.013898272379473914   -0.1274352546880681  ...
# 0   0.9872645822676525       0.010211852167047702  -0.05736949909686946  ...
# 0   0.9819559162791901       0.011767777262349788  -0.21559481268523112  ...
# 0   0.9894438000921387       0.011008431859591156   0.16839370824430916  ...
# 0   0.9877621609760315       0.013037894769508795  -0.28319520702491086  ...
# 0   0.9839151475080773       0.007470767973254615   0.21692922942223333  ...
# 0    0.934040840619822        0.03226090230167143    0.3071400256447004  ...
#
#   Standard Error_Acu-Pd-MLP-LM coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0         0.005334882577522506     0.076973263889796  0.35808074465091444
# 0         0.004457555611756504    0.1724263620632126  0.48289065686112315
# 0          0.00518130672958422   -0.2362698236008851   0.5279033711793427
# 0         0.004553997107237891   0.15314622318480445   0.3406539653452447
# 0         0.007587252677291394    0.6111085492295196   0.3805408805104692
# 0         0.005845065446026582  -0.04692418384286087  0.36096790760420217
# 0         0.004858713965397032   0.17125196666371514   0.3983408849845003
# 0         0.005793600079304415   -0.2658754206837525   0.4283449169442318
# 0         0.005907714843042287  -0.25916312125415913   0.3308372902352297
# 0         0.006458718219542544   0.04228944652119172   0.4544464845900953
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.49951206206154164       0.03245076182211084  0.015182437998358932
# 0  0.45533014446227005       0.04781590000382572  0.018574305679674698
# 0   0.4749581461059963       0.05025089585064562  0.021544802661521832
# 0  0.26231956512610444       0.05171925820819143  0.022865335614578673
# 0   0.4525906242845946       0.03789001181908547  0.018056877317830976
# 0   0.4565278435794189      0.035656907546016144   0.01631244500687257
# 0   0.5446135049811287       0.03297773467008797  0.015554418149303799
# 0  0.26066463478504753       0.06531205708969536  0.019260622208696256
# 0    0.149807345466608       0.07135536575718149  0.021735405719435368
# 0  0.45416659205932186       0.04510506226226334  0.019465914154405285
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8598239688803573      0.9714045972809758
# 0     1.1210614209599783      0.9806473038643702
# 0     1.3031733413236888      0.9568719031007095
# 0     1.1585609826454955      0.9868924385302316
# 0      1.037591178265014      0.9891739721210048
# 0     0.8594589875848374      0.9808361188918542
# 0     0.9331011017994972      0.9827107594182959
# 0     1.3501304766598041       0.980040124579171
# 0     0.8682119285751235       0.976690905012162
# 0     1.2460817299266165      0.9398322602217952
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0          0.013356038569556618     0.3377343861206118
# 0          0.014258170757486966    0.16788915969760693
# 0          0.025048142019355138   -0.14237791718504827
# 0          0.012088294259295734   -0.08667562424356284
# 0          0.009827534680931851   -0.11888947656926649
# 0          0.010876489644693343   -0.13667404230272373
# 0           0.01120531039498603     0.2058194563865765
# 0          0.017444270393107173    -0.5075636235162657
# 0           0.01214311110070748    0.14308363138198188
# 0          0.028544555820146224     0.3351070447764733
#
# [10 rows x 50 columns]

# %%
datos11=pd.read_csv('Prueba1.0.csv',decimal=",", encoding='utf-8',sep=u',')
datos12=pd.read_csv('Prueba2.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos13=pd.read_csv('Prueba3.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos14=pd.read_csv('Prueba4.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos15=pd.read_csv('Prueba5.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos16=pd.read_csv('Prueba6.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos17=pd.read_csv('Prueba7.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
datos18=pd.read_csv('Prueba8.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos19=pd.read_csv('Prueba9.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos110=pd.read_csv('Prueba10.0.csv',decimal=",",sep=u',', encoding='utf-8',dayfirst=True)

# %%
datostotal1 = [datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos110,]

# %%
resultadoDatos= pd.concat(datostotal1)

# %%
#resultadoDatos['Pruebas'] = resultadoDatos['Pruebas'].astype('float')
#resultadoDatos = resultadoDatos.set_index('Pruebas')

# %%
resultadoDatos
# Out:
#    Unnamed: 0 Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP  \
# 0           0     1.0  0.36490655124903987   0.3897614421175062
# 0           0     2.0   0.5134709035385809   0.4151113004995016
# 0           0     3.0   0.6029450222655992   0.4552307239383474
# 0           0     4.0  0.43928274718711874   0.2926406794018279
# 0           0     5.0   0.3304023214292526   0.3752359152166953
# 0           0     6.0  0.41213647488729405    0.446190741652399
# 0           0     7.0   0.6475989799535233   0.5275131757258892
# 0           0     8.0  0.46181148587782683   0.3747603497558605
# 0           0     9.0  0.24312817769474987  0.28307739026682743
# 0           0    10.0  0.48252515948573493  0.38573278451744275
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0   0.041338251855687624  0.017609918690071016  0.9899460704564589
# 0    0.05518108544668105  0.018376335113421054  1.1975262733420031
# 0    0.05971567442715505  0.022844419255337804   1.392693978281973
# 0    0.06183251242073693  0.024970838574049574  1.3427081738814446
# 0   0.038598372043825435  0.018862290456259048  0.9931037385436089
# 0    0.04157008861009052  0.017723405599392623  0.9588549963315194
# 0    0.05548868554758156  0.015707933646817114  1.1771915503815036
# 0    0.05400465909998044  0.019195509821561846  1.2937823208009172
# 0    0.03502990261711806  0.014876213546214878  0.6453799132251243
# 0    0.05512840650241081  0.020260452884830832  1.3409167119734908
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP   coef(b)_Acu-6am-MLP  ...  \
# 0   0.9667606342674128       0.016618755823697835    0.3575594820816234  ...
# 0   0.9729030893385013        0.01809381868621007   0.12334575927979059  ...
# 0   0.9545593206802264       0.027510388880073126  -0.12446739661299758  ...
# 0   0.9870973712846349       0.013898272379473914   -0.1274352546880681  ...
# 0   0.9872645822676525       0.010211852167047702  -0.05736949909686946  ...
# 0   0.9819559162791901       0.011767777262349788  -0.21559481268523112  ...
# 0   0.9894438000921387       0.011008431859591156   0.16839370824430916  ...
# 0   0.9877621609760315       0.013037894769508795  -0.28319520702491086  ...
# 0   0.9839151475080773       0.007470767973254615   0.21692922942223333  ...
# 0    0.934040840619822        0.03226090230167143    0.3071400256447004  ...
#
#   Standard Error_Acu-Pd-MLP-LM coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0         0.005334882577522506     0.076973263889796  0.35808074465091444
# 0         0.004457555611756504    0.1724263620632126  0.48289065686112315
# 0          0.00518130672958422   -0.2362698236008851   0.5279033711793427
# 0         0.004553997107237891   0.15314622318480445   0.3406539653452447
# 0         0.007587252677291394    0.6111085492295196   0.3805408805104692
# 0         0.005845065446026582  -0.04692418384286087  0.36096790760420217
# 0         0.004858713965397032   0.17125196666371514   0.3983408849845003
# 0         0.005793600079304415   -0.2658754206837525   0.4283449169442318
# 0         0.005907714843042287  -0.25916312125415913   0.3308372902352297
# 0         0.006458718219542544   0.04228944652119172   0.4544464845900953
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.49951206206154164       0.03245076182211084  0.015182437998358932
# 0  0.45533014446227005       0.04781590000382572  0.018574305679674698
# 0   0.4749581461059963       0.05025089585064562  0.021544802661521832
# 0  0.26231956512610444       0.05171925820819143  0.022865335614578673
# 0   0.4525906242845946       0.03789001181908547  0.018056877317830976
# 0   0.4565278435794189      0.035656907546016144   0.01631244500687257
# 0   0.5446135049811287       0.03297773467008797  0.015554418149303799
# 0  0.26066463478504753       0.06531205708969536  0.019260622208696256
# 0    0.149807345466608       0.07135536575718149  0.021735405719435368
# 0  0.45416659205932186       0.04510506226226334  0.019465914154405285
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8598239688803573      0.9714045972809758
# 0     1.1210614209599783      0.9806473038643702
# 0     1.3031733413236888      0.9568719031007095
# 0     1.1585609826454955      0.9868924385302316
# 0      1.037591178265014      0.9891739721210048
# 0     0.8594589875848374      0.9808361188918542
# 0     0.9331011017994972      0.9827107594182959
# 0     1.3501304766598041       0.980040124579171
# 0     0.8682119285751235       0.976690905012162
# 0     1.2460817299266165      0.9398322602217952
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0          0.013356038569556618     0.3377343861206118
# 0          0.014258170757486966    0.16788915969760693
# 0          0.025048142019355138   -0.14237791718504827
# 0          0.012088294259295734   -0.08667562424356284
# 0          0.009827534680931851   -0.11888947656926649
# 0          0.010876489644693343   -0.13667404230272373
# 0           0.01120531039498603     0.2058194563865765
# 0          0.017444270393107173    -0.5075636235162657
# 0           0.01214311110070748    0.14308363138198188
# 0          0.028544555820146224     0.3351070447764733
#
# [10 rows x 50 columns]

# %%
resultadoDatos = resultadoDatos.drop(['Unnamed: 0'], axis=1)

# %%
resultadoDatos
# Out:
#   Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP Standard Error_6am-MLP  \
# 0     1.0  0.36490655124903987   0.3897614421175062   0.041338251855687624
# 0     2.0   0.5134709035385809   0.4151113004995016    0.05518108544668105
# 0     3.0   0.6029450222655992   0.4552307239383474    0.05971567442715505
# 0     4.0  0.43928274718711874   0.2926406794018279    0.06183251242073693
# 0     5.0   0.3304023214292526   0.3752359152166953   0.038598372043825435
# 0     6.0  0.41213647488729405    0.446190741652399    0.04157008861009052
# 0     7.0   0.6475989799535233   0.5275131757258892    0.05548868554758156
# 0     8.0  0.46181148587782683   0.3747603497558605    0.05400465909998044
# 0     9.0  0.24312817769474987  0.28307739026682743    0.03502990261711806
# 0    10.0  0.48252515948573493  0.38573278451744275    0.05512840650241081
#
#         coef(b)_6am-MLP coef(a)_Acu-6am-MLP rsquared_Acu-6am-MLP  \
# 0  0.017609918690071016  0.9899460704564589   0.9667606342674128
# 0  0.018376335113421054  1.1975262733420031   0.9729030893385013
# 0  0.022844419255337804   1.392693978281973   0.9545593206802264
# 0  0.024970838574049574  1.3427081738814446   0.9870973712846349
# 0  0.018862290456259048  0.9931037385436089   0.9872645822676525
# 0  0.017723405599392623  0.9588549963315194   0.9819559162791901
# 0  0.015707933646817114  1.1771915503815036   0.9894438000921387
# 0  0.019195509821561846  1.2937823208009172   0.9877621609760315
# 0  0.014876213546214878  0.6453799132251243   0.9839151475080773
# 0  0.020260452884830832  1.3409167119734908    0.934040840619822
#
#   Standard Error_Acu-6am-MLP   coef(b)_Acu-6am-MLP coef(a)_6am-Beysens  ...  \
# 0       0.016618755823697835    0.3575594820816234  0.7207654565257081  ...
# 0        0.01809381868621007   0.12334575927979059  0.6169055416872858  ...
# 0       0.027510388880073126  -0.12446739661299758  0.7679916039079602  ...
# 0       0.013898272379473914   -0.1274352546880681  0.6639553040604037  ...
# 0       0.010211852167047702  -0.05736949909686946  0.6145218191027668  ...
# 0       0.011767777262349788  -0.21559481268523112  0.5943870185845472  ...
# 0       0.011008431859591156   0.16839370824430916  0.7772113476332206  ...
# 0       0.013037894769508795  -0.28319520702491086  0.6003691228724898  ...
# 0       0.007470767973254615   0.21692922942223333  0.6070154112561591  ...
# 0        0.03226090230167143    0.3071400256447004  0.6672384057116422  ...
#
#   Standard Error_Acu-Pd-MLP-LM coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0         0.005334882577522506     0.076973263889796  0.35808074465091444
# 0         0.004457555611756504    0.1724263620632126  0.48289065686112315
# 0          0.00518130672958422   -0.2362698236008851   0.5279033711793427
# 0         0.004553997107237891   0.15314622318480445   0.3406539653452447
# 0         0.007587252677291394    0.6111085492295196   0.3805408805104692
# 0         0.005845065446026582  -0.04692418384286087  0.36096790760420217
# 0         0.004858713965397032   0.17125196666371514   0.3983408849845003
# 0         0.005793600079304415   -0.2658754206837525   0.4283449169442318
# 0         0.005907714843042287  -0.25916312125415913   0.3308372902352297
# 0         0.006458718219542544   0.04228944652119172   0.4544464845900953
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.49951206206154164       0.03245076182211084  0.015182437998358932
# 0  0.45533014446227005       0.04781590000382572  0.018574305679674698
# 0   0.4749581461059963       0.05025089585064562  0.021544802661521832
# 0  0.26231956512610444       0.05171925820819143  0.022865335614578673
# 0   0.4525906242845946       0.03789001181908547  0.018056877317830976
# 0   0.4565278435794189      0.035656907546016144   0.01631244500687257
# 0   0.5446135049811287       0.03297773467008797  0.015554418149303799
# 0  0.26066463478504753       0.06531205708969536  0.019260622208696256
# 0    0.149807345466608       0.07135536575718149  0.021735405719435368
# 0  0.45416659205932186       0.04510506226226334  0.019465914154405285
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8598239688803573      0.9714045972809758
# 0     1.1210614209599783      0.9806473038643702
# 0     1.3031733413236888      0.9568719031007095
# 0     1.1585609826454955      0.9868924385302316
# 0      1.037591178265014      0.9891739721210048
# 0     0.8594589875848374      0.9808361188918542
# 0     0.9331011017994972      0.9827107594182959
# 0     1.3501304766598041       0.980040124579171
# 0     0.8682119285751235       0.976690905012162
# 0     1.2460817299266165      0.9398322602217952
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0          0.013356038569556618     0.3377343861206118
# 0          0.014258170757486966    0.16788915969760693
# 0          0.025048142019355138   -0.14237791718504827
# 0          0.012088294259295734   -0.08667562424356284
# 0          0.009827534680931851   -0.11888947656926649
# 0          0.010876489644693343   -0.13667404230272373
# 0           0.01120531039498603     0.2058194563865765
# 0          0.017444270393107173    -0.5075636235162657
# 0           0.01214311110070748    0.14308363138198188
# 0          0.028544555820146224     0.3351070447764733
#
# [10 rows x 49 columns]

# %%
resultadoDatos=resultadoDatos.astype(float)

# %%
resultadoDatos
# Out:
#    Pruebas  coef(a)_6am-MLP  rsquared_6am-MLP  Standard Error_6am-MLP  \
# 0      1.0         0.364907          0.389761                0.041338
# 0      2.0         0.513471          0.415111                0.055181
# 0      3.0         0.602945          0.455231                0.059716
# 0      4.0         0.439283          0.292641                0.061833
# 0      5.0         0.330402          0.375236                0.038598
# 0      6.0         0.412136          0.446191                0.041570
# 0      7.0         0.647599          0.527513                0.055489
# 0      8.0         0.461811          0.374760                0.054005
# 0      9.0         0.243128          0.283077                0.035030
# 0     10.0         0.482525          0.385733                0.055128
#
#    coef(b)_6am-MLP  coef(a)_Acu-6am-MLP  rsquared_Acu-6am-MLP  \
# 0         0.017610             0.989946              0.966761
# 0         0.018376             1.197526              0.972903
# 0         0.022844             1.392694              0.954559
# 0         0.024971             1.342708              0.987097
# 0         0.018862             0.993104              0.987265
# 0         0.017723             0.958855              0.981956
# 0         0.015708             1.177192              0.989444
# 0         0.019196             1.293782              0.987762
# 0         0.014876             0.645380              0.983915
# 0         0.020260             1.340917              0.934041
#
#    Standard Error_Acu-6am-MLP  coef(b)_Acu-6am-MLP  coef(a)_6am-Beysens  ...  \
# 0                    0.016619             0.357559             0.720765  ...
# 0                    0.018094             0.123346             0.616906  ...
# 0                    0.027510            -0.124467             0.767992  ...
# 0                    0.013898            -0.127435             0.663955  ...
# 0                    0.010212            -0.057369             0.614522  ...
# 0                    0.011768            -0.215595             0.594387  ...
# 0                    0.011008             0.168394             0.777211  ...
# 0                    0.013038            -0.283195             0.600369  ...
# 0                    0.007471             0.216929             0.607015  ...
# 0                    0.032261             0.307140             0.667238  ...
#
#    Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  coef(a)_6am-MLP-LM  \
# 0                      0.005335               0.076973            0.358081
# 0                      0.004458               0.172426            0.482891
# 0                      0.005181              -0.236270            0.527903
# 0                      0.004554               0.153146            0.340654
# 0                      0.007587               0.611109            0.380541
# 0                      0.005845              -0.046924            0.360968
# 0                      0.004859               0.171252            0.398341
# 0                      0.005794              -0.265875            0.428345
# 0                      0.005908              -0.259163            0.330837
# 0                      0.006459               0.042289            0.454446
#
#    rsquared_6am-MLP-LM  Standard Error_6am-MLP-LM  coef(b)_6am-MLP-LM  \
# 0             0.499512                   0.032451            0.015182
# 0             0.455330                   0.047816            0.018574
# 0             0.474958                   0.050251            0.021545
# 0             0.262320                   0.051719            0.022865
# 0             0.452591                   0.037890            0.018057
# 0             0.456528                   0.035657            0.016312
# 0             0.544614                   0.032978            0.015554
# 0             0.260665                   0.065312            0.019261
# 0             0.149807                   0.071355            0.021735
# 0             0.454167                   0.045105            0.019466
#
#    coef(a)_Acu-6am-MLP-LM  rsquared_Acu-6am-MLP-LM  \
# 0                0.859824                 0.971405
# 0                1.121061                 0.980647
# 0                1.303173                 0.956872
# 0                1.158561                 0.986892
# 0                1.037591                 0.989174
# 0                0.859459                 0.980836
# 0                0.933101                 0.982711
# 0                1.350130                 0.980040
# 0                0.868212                 0.976691
# 0                1.246082                 0.939832
#
#    Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0                       0.013356                0.337734
# 0                       0.014258                0.167889
# 0                       0.025048               -0.142378
# 0                       0.012088               -0.086676
# 0                       0.009828               -0.118889
# 0                       0.010876               -0.136674
# 0                       0.011205                0.205819
# 0                       0.017444               -0.507564
# 0                       0.012143                0.143084
# 0                       0.028545                0.335107
#
# [10 rows x 49 columns]

# %%
#mean_df = df['R-cuadrado-Modelo-Beysens(6am)'].mean()
#print(mean_df)

# %% [markdown]
# # Resultados de Pruebas a modelo test ADAMAX

# %%
import matplotlib.pyplot as plt

# %%
#Graficos

# %% [markdown]
# ## grafico 1, modelo R cuadrado

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo MLP  6AM")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
mean_df1 = resultadoDatos['rsquared_6am-Beysens'].mean()
print(mean_df1)
# Out:
# 0.37676417067582124

# %%
mean_df = resultadoDatos['rsquared_6am-MLP'].mean()
print(mean_df)
# Out:
# 0.3945254503092297

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-MLP']))
# Out:
# 0.07411550205147134
# 0.07312688641846382

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP 6AM")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df111 = resultadoDatos['coef(a)_6am-Beysens'].mean()
print(mean_df111)
# Out:
# 0.6630361031342183

# %%
mean_df = resultadoDatos['coef(a)_6am-MLP'].mean()
print(mean_df)
# Out:
# 0.44982078235687206

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-MLP']))
# Out:
# 0.06965203651564453
# 0.12181594721575055

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP 6AM")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df1145 = resultadoDatos['coef(b)_6am-Beysens'].mean()
print(mean_df1145)
# Out:
# 0.014036491270021583

# %%
mean_df1245 = resultadoDatos['coef(b)_6am-MLP'].mean()
print(mean_df1245)
# Out:
# 0.019042731758795582

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-MLP']))
# Out:
# 0.0022923327816964643
# 0.003052365838939503

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP 6AM")
plt.ylabel('Resultados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df114 = resultadoDatos['Standard Error_6am-Beysens'].mean()
print(mean_df114)
# Out:
# 0.07778570021813361

# %%
mean_df124 = resultadoDatos['Standard Error_6am-MLP'].mean()
print(mean_df124)
# Out:
# 0.049788763857126744

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-MLP']))
# Out:
# 0.009552847807257679
# 0.009623200313992854

# %% [markdown]
# ## grafico 2

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo Acumulado MLP 6AM")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-Beysens'].mean()
print(mean_df11)
# Out:
# 0.9767816657921629

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-MLP'].mean()
print(mean_df11)
# Out:
# 0.9745702863313687

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-MLP']))
# Out:
# 0.015500126615267113
# 0.018141538775431044

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP 6AM")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11112 = resultadoDatos['coef(a)_Acu-6am-Beysens'].mean()
print(mean_df11112)
# Out:
# 1.163347520212629

# %%
mean_df11111 = resultadoDatos['coef(a)_Acu-6am-MLP'].mean()
print(mean_df11111)
# Out:
# 1.1332103727218044

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-MLP']))
# Out:
# 0.13609603277769738
# 0.2344615834238729

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP 6AM")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df63 = resultadoDatos['coef(b)_Acu-6am-Beysens'].mean()
print(mean_df63)
# Out:
# 0.04430830109938727

# %%
mean_df64= resultadoDatos['coef(b)_Acu-6am-MLP'].mean()
print(mean_df64)
# Out:
# 0.03653060345645798

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-MLP']))
# Out:
# 0.16896527111807969
# 0.22636539328635988

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas1= resultadoDatos['Pruebas']
resultados1={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-6am-MLP']}
ax.plot(pruebas1,resultados1['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas1,resultados1['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP 6AM")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-Beysens'].mean()
print(mean_df6)
# Out:
# 0.01570370546803672

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-MLP'].mean()
print(mean_df6)
# Out:
# 0.016187886210287845

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Out:
# 0.006795129221731484
# 0.015288446795055383

# %% [markdown]
# ## grafico 3

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo MLP PD")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['rsquared_Beysens-PM'].mean()
print(mean_df6)
# Out:
# 0.012495561078624462

# %%
mean_df7 = resultadoDatos['rsquared_MLP-PM'].mean()
print(mean_df7)
# Out:
# 0.24998340730505975

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_MLP-PM']))
# Out:
# 0.015288446795055383
# 0.0873026118016575

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP PD")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df77 = resultadoDatos['coef(a)_Beysens-PM'].mean()
print(mean_df77)
# Out:
# -0.0002450503650709162

# %%
mean_df78 = resultadoDatos['coef(a)_MLP-PM'].mean()
print(mean_df78)
# Out:
# 0.2725086127787663

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_MLP-PM']))
# Out:
# 0.001688765725735695
# 0.05366364966601497

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP PD")
plt.ylabel('Resultados de coeficiente')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df781 = resultadoDatos['coef(b)_Beysens-PM'].mean()
print(mean_df781)
# Out:
# 0.0029564728899676624

# %%
mean_df786 = resultadoDatos['coef(b)_MLP-PM'].mean()
print(mean_df786)
# Out:
# 0.02462600502446081

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_MLP-PM']))
# Out:
# 0.003880961679237666
# 0.0026448934236246798

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP PD")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864 = resultadoDatos['Standard Error_Beysens-PM'].mean()
print(mean_df7864)
# Out:
# 0.0013654860514191178

# %%
mean_df7865 = resultadoDatos['Standard Error_MLP-PM'].mean()
print(mean_df7865)
# Out:
# 0.043831251071499586

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_MLP-PM']))
# Out:
# 0.0006921739995859917
# 0.008156046581249203

# %% [markdown]
# ## grafico 4

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo Acumulado MLP PD")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df8 = resultadoDatos['rsquared_Acu-Beysens-PM'].mean()
print(mean_df8)
# Out:
# 0.7812558908882473

# %%
mean_df9 = resultadoDatos['rsquared_Acu-MLP-PM'].mean()
print(mean_df9)
# Out:
# 0.9603724624126878

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-MLP-PM']))
# Out:
# 0.13186363053339406
# 0.03193172482161341

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP PD")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df78649 = resultadoDatos['coef(a)_Acu-Beysens-PM'].mean()
print(mean_df78649)
# Out:
# 0.09502362913724591

# %%
mean_df78648 = resultadoDatos['coef(a)_Acu-MLP-PM'].mean()
print(mean_df78648)
# Out:
# 1.1739866754470367

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-MLP-PM']))
# Out:
# 0.07204187633466978
# 0.1967437896109214

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP PD")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Beysens-PM'].mean()
print(mean_df786489)
# Out:
# 0.0008436371456127603

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-MLP-PM'].mean()
print(mean_df786489)
# Out:
# 0.0636596673318183

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-MLP-PM']))
# Out:
# 0.08030612048746559
# 0.24419500343266828

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo de Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Acumulado Modelo MLP PD")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864899 = resultadoDatos['Standard Error_Acu-Beysens-PM'].mean()
print(mean_df7864899)
# Out:
# 0.003705321993220277

# %%
mean_df78648999 = resultadoDatos['Standard Error_Acu-MLP-PM'].mean()
print(mean_df78648999)
# Out:
# 0.021409718269827016

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-MLP-PM']))
# Out:
# 0.0022899510162110843
# 0.011668546958655043

# %%
#########################################################################################

# %% [markdown]
# # Resultados de Pruebas LM

# %%
import matplotlib.pyplot as plt

# %%
#Graficos

# %%
resultadoDatos
# Out:
#    Pruebas  coef(a)_6am-MLP  rsquared_6am-MLP  Standard Error_6am-MLP  \
# 0      1.0         0.364907          0.389761                0.041338
# 0      2.0         0.513471          0.415111                0.055181
# 0      3.0         0.602945          0.455231                0.059716
# 0      4.0         0.439283          0.292641                0.061833
# 0      5.0         0.330402          0.375236                0.038598
# 0      6.0         0.412136          0.446191                0.041570
# 0      7.0         0.647599          0.527513                0.055489
# 0      8.0         0.461811          0.374760                0.054005
# 0      9.0         0.243128          0.283077                0.035030
# 0     10.0         0.482525          0.385733                0.055128
#
#    coef(b)_6am-MLP  coef(a)_Acu-6am-MLP  rsquared_Acu-6am-MLP  \
# 0         0.017610             0.989946              0.966761
# 0         0.018376             1.197526              0.972903
# 0         0.022844             1.392694              0.954559
# 0         0.024971             1.342708              0.987097
# 0         0.018862             0.993104              0.987265
# 0         0.017723             0.958855              0.981956
# 0         0.015708             1.177192              0.989444
# 0         0.019196             1.293782              0.987762
# 0         0.014876             0.645380              0.983915
# 0         0.020260             1.340917              0.934041
#
#    Standard Error_Acu-6am-MLP  coef(b)_Acu-6am-MLP  coef(a)_6am-Beysens  ...  \
# 0                    0.016619             0.357559             0.720765  ...
# 0                    0.018094             0.123346             0.616906  ...
# 0                    0.027510            -0.124467             0.767992  ...
# 0                    0.013898            -0.127435             0.663955  ...
# 0                    0.010212            -0.057369             0.614522  ...
# 0                    0.011768            -0.215595             0.594387  ...
# 0                    0.011008             0.168394             0.777211  ...
# 0                    0.013038            -0.283195             0.600369  ...
# 0                    0.007471             0.216929             0.607015  ...
# 0                    0.032261             0.307140             0.667238  ...
#
#    Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  coef(a)_6am-MLP-LM  \
# 0                      0.005335               0.076973            0.358081
# 0                      0.004458               0.172426            0.482891
# 0                      0.005181              -0.236270            0.527903
# 0                      0.004554               0.153146            0.340654
# 0                      0.007587               0.611109            0.380541
# 0                      0.005845              -0.046924            0.360968
# 0                      0.004859               0.171252            0.398341
# 0                      0.005794              -0.265875            0.428345
# 0                      0.005908              -0.259163            0.330837
# 0                      0.006459               0.042289            0.454446
#
#    rsquared_6am-MLP-LM  Standard Error_6am-MLP-LM  coef(b)_6am-MLP-LM  \
# 0             0.499512                   0.032451            0.015182
# 0             0.455330                   0.047816            0.018574
# 0             0.474958                   0.050251            0.021545
# 0             0.262320                   0.051719            0.022865
# 0             0.452591                   0.037890            0.018057
# 0             0.456528                   0.035657            0.016312
# 0             0.544614                   0.032978            0.015554
# 0             0.260665                   0.065312            0.019261
# 0             0.149807                   0.071355            0.021735
# 0             0.454167                   0.045105            0.019466
#
#    coef(a)_Acu-6am-MLP-LM  rsquared_Acu-6am-MLP-LM  \
# 0                0.859824                 0.971405
# 0                1.121061                 0.980647
# 0                1.303173                 0.956872
# 0                1.158561                 0.986892
# 0                1.037591                 0.989174
# 0                0.859459                 0.980836
# 0                0.933101                 0.982711
# 0                1.350130                 0.980040
# 0                0.868212                 0.976691
# 0                1.246082                 0.939832
#
#    Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0                       0.013356                0.337734
# 0                       0.014258                0.167889
# 0                       0.025048               -0.142378
# 0                       0.012088               -0.086676
# 0                       0.009828               -0.118889
# 0                       0.010876               -0.136674
# 0                       0.011205                0.205819
# 0                       0.017444               -0.507564
# 0                       0.012143                0.143084
# 0                       0.028545                0.335107
#
# [10 rows x 49 columns]

# %% [markdown]
# ## grafico 1, modelo R cuadrado

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo MLP LM 6AM")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
mean_df1 = resultadoDatos['rsquared_6am-Beysens'].mean()
print(mean_df1)
# Out:
# 0.37676417067582124

# %%
mean_df = resultadoDatos['rsquared_6am-MLP-LM'].mean()
print(mean_df)
# Out:
# 0.4010490462912033

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-MLP-LM']))
# Out:
# 0.07411550205147134
# 0.12881798570857764

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP LM 6AM")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df111 = resultadoDatos['coef(a)_6am-Beysens'].mean()
print(mean_df111)
# Out:
# 0.6630361031342183

# %%
mean_df = resultadoDatos['coef(a)_6am-MLP-LM'].mean()
print(mean_df)
# Out:
# 0.4063007102905353

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-MLP-LM']))
# Out:
# 0.06965203651564453
# 0.06546293973103254

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP LM 6AM")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df1145 = resultadoDatos['coef(b)_6am-Beysens'].mean()
print(mean_df1145)
# Out:
# 0.014036491270021583

# %%
mean_df1245 = resultadoDatos['coef(b)_6am-MLP-LM'].mean()
print(mean_df1245)
# Out:
# 0.01885525645106784

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-MLP-LM']))
# Out:
# 0.0022923327816964643
# 0.0026607066573873578

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP LM 6AM")
plt.ylabel('Resultados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df114 = resultadoDatos['Standard Error_6am-Beysens'].mean()
print(mean_df114)
# Out:
# 0.07778570021813361

# %%
mean_df124 = resultadoDatos['Standard Error_6am-MLP-LM'].mean()
print(mean_df124)
# Out:
# 0.047053395502910336

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-MLP-LM']))
# Out:
# 0.009552847807257679
# 0.013272966915057659

# %% [markdown]
# ## grafico 2

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo Acumulado MLP LM 6AM")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-Beysens'].mean()
print(mean_df11)
# Out:
# 0.9767816657921629

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-MLP-LM'].mean()
print(mean_df11)
# Out:
# 0.9745100383020571

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-MLP-LM']))
# Out:
# 0.015500126615267113
# 0.015172804052112998

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP LM 6AM")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11112 = resultadoDatos['coef(a)_Acu-6am-Beysens'].mean()
print(mean_df11112)
# Out:
# 1.163347520212629

# %%
mean_df11111 = resultadoDatos['coef(a)_Acu-6am-MLP-LM'].mean()
print(mean_df11111)
# Out:
# 1.0737195116620413

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-MLP-LM']))
# Out:
# 0.13609603277769738
# 0.18949382374846802

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP LM 6AM")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df63 = resultadoDatos['coef(b)_Acu-6am-Beysens'].mean()
print(mean_df63)
# Out:
# 0.04430830109938727

# %%
mean_df64= resultadoDatos['coef(b)_Acu-6am-MLP-LM'].mean()
print(mean_df64)
# Out:
# 0.01974529945463834

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-MLP-LM']))
# Out:
# 0.16896527111807969
# 0.26493254722191917

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas1= resultadoDatos['Pruebas']
resultados1={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-6am-MLP-LM']}
ax.plot(pruebas1,resultados1['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas1,resultados1['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP LM 6AM")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-Beysens'].mean()
print(mean_df6)
# Out:
# 0.01570370546803672

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-MLP-LM'].mean()
print(mean_df6)
# Out:
# 0.015479191764026656

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-MLP-LM']))
# Out:
# 0.006795129221731484
# 0.006378335984082428

# %% [markdown]
# ## grafico 3

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo MLP LM PD")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['rsquared_Beysens-PM'].mean()
print(mean_df6)
# Out:
# 0.012495561078624462

# %%
mean_df7 = resultadoDatos['rsquared_Pd-MLP-LM'].mean()
print(mean_df7)
# Out:
# 0.2712485214576015

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Pd-MLP-LM']))
# Out:
# 0.015288446795055383
# 0.0939532372371988

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP LM PD")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df77 = resultadoDatos['coef(a)_Beysens-PM'].mean()
print(mean_df77)
# Out:
# -0.0002450503650709162

# %%
mean_df78 = resultadoDatos['coef(a)_Pd-MLP-LM'].mean()
print(mean_df78)
# Out:
# 0.3077580811316259

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Pd-MLP-LM']))
# Out:
# 0.001688765725735695
# 0.04931437087262537

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP LM PD")
plt.ylabel('Resultados coef b')
plt.xlabel('Resultados de coeficientes')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df781 = resultadoDatos['coef(b)_Beysens-PM'].mean()
print(mean_df781)
# Out:
# 0.0029564728899676624

# %%
mean_df786 = resultadoDatos['coef(b)_Pd-MLP-LM'].mean()
print(mean_df786)
# Out:
# 0.02283815364941175

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Pd-MLP-LM']))
# Out:
# 0.003880961679237666
# 0.003022482428459994

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP LM PD")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864 = resultadoDatos['Standard Error_Beysens-PM'].mean()
print(mean_df7864)
# Out:
# 0.0013654860514191178

# %%
mean_df7865 = resultadoDatos['Standard Error_Pd-MLP-LM'].mean()
print(mean_df7865)
# Out:
# 0.04693371204497775

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Pd-MLP-LM']))
# Out:
# 0.0006921739995859917
# 0.008327301598741352

# %% [markdown]
# ## grafico 4

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo Acumulado MLP LM PD")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df8 = resultadoDatos['rsquared_Acu-Beysens-PM'].mean()
print(mean_df8)
# Out:
# 0.7812558908882473

# %%
mean_df9 = resultadoDatos['rsquared_Acu-Pd-MLP-LM'].mean()
print(mean_df9)
# Out:
# 0.9928795926689779

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Pd-MLP-LM']))
# Out:
# 0.13186363053339406
# 0.002592535941388714

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP LM PD")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df78649 = resultadoDatos['coef(a)_Acu-Beysens-PM'].mean()
print(mean_df78649)
# Out:
# 0.09502362913724591

# %%
mean_df78648 = resultadoDatos['coef(a)_Acu-Pd-MLP-LM'].mean()
print(mean_df78648)
# Out:
# 1.0383933843325028

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Pd-MLP-LM']))
# Out:
# 0.07204187633466978
# 0.057171759538634466

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP LM PD")
plt.ylabel('Resultados Coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Beysens-PM'].mean()
print(mean_df786489)
# Out:
# 0.0008436371456127603

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Pd-MLP-LM'].mean()
print(mean_df786489)
# Out:
# 0.04189632621705818

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Pd-MLP-LM']))
# Out:
# 0.08030612048746559
# 0.2670843274010518

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo de Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Acumulado Modelo MLP LM PD")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864899 = resultadoDatos['Standard Error_Acu-Beysens-PM'].mean()
print(mean_df7864899)
# Out:
# 0.003705321993220277

# %%
mean_df78648999 = resultadoDatos['Standard Error_Acu-Pd-MLP-LM'].mean()
print(mean_df78648999)
# Out:
# 0.005597880725670538

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Pd-MLP-LM']))
# Out:
# 0.0022899510162110843
# 0.000947109595811056

# %% [markdown]
# ## Combinacion entre los modelos para tabla de conclusion.

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-Acumulado-MLP(6am)")
#ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="M Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="M Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="M Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
#cambiar 
#resultado6=pd.merge(df5, df6, on='Pruebas', suffixes=('_Beysens-PM', '_Acu-Beysens-PM'))

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-MLP-6am-LM")
plt.ylabel('Resultado R cuadrado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %% [markdown]
# resultados con modelo LM

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="M Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="M Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="M Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP'],'Modelo RNA(6am)1':resultadoDatos['rsquared_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = '^',label="Modelo-MLP(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)1'],c='red', marker = 'o',label="Modelo-MLP-6am-LM")
plt.ylabel('Resultado R cuadrado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
# Connect to the MySQL database
import pandas as pd
from sqlalchemy import create_engine
# Read CSV file into a DataFrame
#df = pd.read_csv("Prueba"+str(n)+".csv")
# Create a database engine
engine = create_engine('mysql+pymysql://root:sSeCr4t100114@159.203.136.164/demo')

# %%
from sqlalchemy import create_engine
import pandas as pd

# Create engine
engine = create_engine('mysql+pymysql://root:sSeCr4t100114@159.203.136.164/demo')

# Get data from engine
data = pd.read_sql_table('prueba', engine)

# Export data to CSV
data.to_csv('prueba.csv', index=False)

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
pwd
# Out:
# '/root/notebooks/resultados-31-01'

# %%
cat prueba.csv
# Out:
# Unnamed: 0,Pruebas,coef(a)_6am-MLP,rsquared_6am-MLP,Standard Error_6am-MLP,coef(b)_6am-MLP,coef(a)_Acu-6am-MLP,rsquared_Acu-6am-MLP,Standard Error_Acu-6am-MLP,coef(b)_Acu-6am-MLP,coef(a)_6am-Beysens,rsquared_6am-Beysens,Standard Error_6am-Beysens,coef(b)_6am-Beysens,coef(a)_Acu-6am-Beysens,rsquared_Acu-6am-Beysens,Standard Error_Acu-6am-Beysens,coef(b)_Acu-6am-Beysens,coef(a)_Beysens-PM,rsquared_Beysens-PM,Standard Error_Beysens-PM,coef(b)_Beysens-PM,coef(a)_Acu-Beysens-PM,rsquared_Acu-Beysens-PM,Standard Error_Acu-Beysens-PM,coef(b)_Acu-Beysens-PM,coef(a)_MLP-PM,rsquared_MLP-PM,Standard Error_MLP-PM,coef(b)_MLP-PM,coef(a)_Acu-MLP-PM,rsquared_Acu-MLP-PM,Standard Error_Acu-MLP-PM,coef(b)_Acu-MLP-PM,coef(a)_Pd-MLP-LM,rsquared_Pd-MLP-LM,Standard Error_Pd-MLP-LM,coef(b)_Pd-MLP-LM,coef(a)_Acu-Pd-MLP-LM,rsquared_Acu-Pd-MLP-LM,Standard Error_Acu-Pd-MLP-LM,coef(b)_Acu-Pd-MLP-LM,coef(a)_6am-MLP-LM,rsquared_6am-MLP-LM,Standard Error_6am-MLP-LM,coef(b)_6am-MLP-LM,coef(a)_Acu-6am-MLP-LM,rsquared_Acu-6am-MLP-LM,Standard Error_Acu-6am-MLP-LM,coef(b)_Acu-6am-MLP-LM
# 0,1.0,0.3649065512490399,0.3897614421175062,0.04133825185568762,0.017609918690071016,0.9899460704564588,0.9667606342674128,0.016618755823697838,0.3575594820816234,0.7207654565257081,0.4087086469688945,0.078488838087632,0.011647812245876596,1.0207366625692842,0.9593974753898264,0.019011265722787087,0.3748132587884694,0.00034162530134862365,0.002794080674283439,0.0005843096591115973,0.0003433422447388802,0.020216838682489725,0.6265504487300235,0.0014130947362643196,0.02246650131301793,0.2414162208515845,0.2394601831390448,0.0389520984428776,0.02679399806777294,1.2605059852828988,0.9667466886020076,0.021165381415740942,0.31254176551095514,0.3033363562308672,0.2619013224526168,0.046103395584501716,0.025233091575273276,0.9346640488946122,0.992241685816706,0.005334882577522506,0.07697326388979599,0.35808074465091444,0.4995120620615416,0.03245076182211084,0.015182437998358932,0.8598239688803573,0.9714045972809758,0.01335603856955662,0.3377343861206118
# 0,2.0,0.5134709035385809,0.4151113004995016,0.05518108544668105,0.018376335113421054,1.1975262733420031,0.9729030893385012,0.01809381868621007,0.1233457592797906,0.6169055416872858,0.30019196451909025,0.08527636645358161,0.016318089244837575,1.307317516600304,0.9748029327257248,0.019029078125333776,0.17576186501480076,-0.0004991295494871052,0.0006431954006187457,0.0017812389708302926,0.004700669385345239,0.14884064374616035,0.8631285608633004,0.00536611897483525,-0.032634591450636664,0.17981066600066994,0.1450315347754373,0.03952568405773788,0.02490437651929369,1.0494999355872079,0.9666321017820708,0.017653723414482625,0.09788389009800476,0.23114580646856386,0.23017100295198845,0.03827171144307437,0.02266461018694673,1.0063525870907,0.9953133311503084,0.004457555611756504,0.1724263620632126,0.4828906568611232,0.4553301444622701,0.04781590000382572,0.018574305679674698,1.1210614209599783,0.9806473038643702,0.014258170757486966,0.16788915969760693
# 0,3.0,0.6029450222655992,0.4552307239383474,0.05971567442715505,0.022844419255337804,1.392693978281973,0.9545593206802264,0.02751038888007313,-0.12446739661299758,0.7679916039079602,0.38986233313169694,0.08698309099962306,0.01377856083892739,1.1279100590035331,0.9710283475770152,0.01763864555758771,0.1185227788274495,-0.0033180415776504065,0.01997763834768962,0.002104010135801612,0.008972274985748973,0.13659139707263238,0.8670239888112931,0.004843000631014706,0.14509358753729806,0.3630344732123621,0.2950994810937827,0.05079812404411268,0.02649854709106816,1.3519341658038275,0.962454382440105,0.024174927389269445,-0.03380163967932833,0.3876066076872895,0.28655472820284456,0.05537168874155673,0.02510886858667308,1.0728117197415754,0.9944330365034184,0.00518130672958422,-0.2362698236008851,0.5279033711793427,0.4749581461059963,0.05025089585064562,0.021544802661521832,1.3031733413236888,0.9568719031007096,0.025048142019355138,-0.14237791718504827
# 0,4.0,0.4392827471871187,0.2926406794018279,0.061832512420736924,0.02497083857404957,1.3427081738814446,0.9870973712846348,0.013898272379473914,-0.1274352546880681,0.6639553040604037,0.3726131899181978,0.07800052202323536,0.015376185201628782,1.2774016706722686,0.9854393676219536,0.0140579737812761,0.018430507213999053,-7.198571784643732e-05,8.874039333917061e-06,0.0021877808815478914,0.005527112610939617,0.2448375793655229,0.8706989646681556,0.008542109788042849,-0.0743772728853313,0.2399628170496086,0.1249007074669206,0.0575056131665863,0.024217510987653932,1.1189036215405908,0.9726527174075918,0.01698599335333829,-0.05792688637140182,0.23927651743292996,0.12746979346360476,0.05667699796891713,0.023896807008262518,1.0159477118458111,0.9952008451286298,0.004553997107237891,0.15314622318480445,0.3406539653452447,0.26231956512610444,0.05171925820819143,0.022865335614578677,1.1585609826454957,0.9868924385302316,0.012088294259295734,-0.08667562424356284
# 0,5.0,0.3304023214292526,0.3752359152166953,0.038598372043825435,0.018862290456259048,0.9931037385436088,0.9872645822676523,0.0102118521670477,-0.05736949909686946,0.6145218191027668,0.4068470799717328,0.06717769942246023,0.013132467001942306,1.10209280425159,0.9909601434339452,0.009529956704071006,-0.11079091578839476,0.0003918373924477624,0.0006434859269648374,0.0013980305427229991,0.0011742865532222589,0.07192411055450465,0.7900365363730003,0.003356934447322586,-0.02002902409609288,0.26043524916690325,0.25008014861145844,0.0408307804129744,0.02345877459767881,1.141925539287961,0.967748475574417,0.018873469606254342,-0.03440438257440706,0.27437024749606864,0.2155338100453431,0.047389980329170384,0.02186101066202216,1.0054094819159132,0.9865166195417672,0.007587252677291394,0.6111085492295196,0.3805408805104692,0.4525906242845946,0.03789001181908547,0.018056877317830976,1.037591178265014,0.9891739721210048,0.009827534680931851,-0.11888947656926648
# 0,6.0,0.4121364748872941,0.446190741652399,0.04157008861009052,0.017723405599392623,0.9588549963315194,0.98195591627919,0.011767777262349788,-0.21559481268523112,0.5943870185845472,0.3453363529499359,0.0740930315022954,0.016465003059329648,1.037503439573568,0.982876537132,0.012398123098937244,0.09812708462117244,0.001000313406087541,0.002338291703871009,0.0018706755987666077,0.0012069062231506453,0.13108389671725354,0.9093099194706324,0.0037479462778474476,-0.1041011907485384,0.32053864666909715,0.3638837493924354,0.038369611353291005,0.021476535109778025,1.0378048190695726,0.9616112605589624,0.018773183441274342,-0.3561888575867663,0.3557750301804016,0.3906934897336498,0.04022493504142979,0.01947644145455497,1.091431434791657,0.9931637499201492,0.005845065446026582,-0.046924183842860866,0.36096790760420217,0.4565278435794189,0.035656907546016144,0.01631244500687257,0.8594589875848374,0.9808361188918542,0.010876489644693343,-0.13667404230272373
# 0,7.0,0.6475989799535233,0.5275131757258892,0.05548868554758156,0.015707933646817114,1.1771915503815036,0.9894438000921388,0.011008431859591156,0.16839370824430916,0.7772113476332206,0.528244619370339,0.06649670218851937,0.009190386285052126,1.0648297111879406,0.9936653810885976,0.007697335420850954,-0.08652126872581087,0.001044729670313193,0.03746076292594913,0.00047945176927932843,-0.0010106122093690383,0.01873666876784779,0.5135130139265961,0.0016510960950464392,-0.02023892134580225,0.24788105133025864,0.35555344555689616,0.03021373437137538,0.019438972401250632,0.9313313670881146,0.9801818127636166,0.011989552081759423,0.05130956188706299,0.32073969292164395,0.4407655115490042,0.032708903423082136,0.016456481388245854,1.0367989546141816,0.9947569765334484,0.004858713965397032,0.17125196666371514,0.3983408849845003,0.5446135049811287,0.032977734670087966,0.0155544181493038,0.9331011017994972,0.982710759418296,0.01120531039498603,0.2058194563865765
# 0,8.0,0.4618114858778268,0.3747603497558605,0.05400465909998044,0.019195509821561846,1.2937823208009172,0.9877621609760316,0.013037894769508795,-0.2831952070249109,0.6003691228724898,0.2563321449574152,0.09258196663925472,0.01569388782199454,1.335142614517388,0.9474501274621869,0.02846789770738972,-0.1821325633766886,-0.003190823446057149,0.022388098536710862,0.0019089629276202989,0.009159828233464763,0.09951108746114462,0.7726999899208267,0.004886364172904984,0.13166685711498985,0.2711018410931514,0.17664058243540814,0.05299099173391465,0.028165862644711038,1.3620653325914758,0.9824174713284448,0.016497215681892278,-0.0813544940343498,0.30144665513701785,0.1811308523528472,0.05802853987531685,0.02552873071482017,1.0003060953278726,0.9920134356973028,0.005793600079304415,-0.2658754206837525,0.4283449169442318,0.26066463478504753,0.06531205708969537,0.019260622208696256,1.350130476659804,0.9800401245791709,0.017444270393107173,-0.5075636235162657
# 0,9.0,0.2431281776947499,0.28307739026682743,0.03502990261711806,0.014876213546214878,0.6453799132251243,0.9839151475080772,0.0074707679732546155,0.21692922942223333,0.6070154112561591,0.4185126745679151,0.06477920605808885,0.013563958960677143,1.019042509679376,0.993890030729859,0.007233737277787369,-0.09897243204734688,0.00031416738682913997,0.00205340938160592,0.0006270426229239884,0.0006968489129626593,0.04790833519214749,0.9036663395864069,0.0014161724537119465,-0.011509244382077469,0.2652289920737921,0.20721163050613745,0.0469691428250061,0.024735582226941426,0.9536806818553468,0.9716748451546601,0.014741739661085497,0.5357324816047822,0.3237501713264938,0.25834708490299163,0.04966250626264521,0.02222277936001141,1.1224173938487791,0.9933951410913802,0.005907714843042287,-0.25916312125415913,0.3308372902352297,0.14980734546660798,0.07135536575718149,0.021735405719435368,0.8682119285751235,0.976690905012162,0.01214311110070748,0.14308363138198188
# 0,10.0,0.4449333222821231,0.32877240491096194,0.05755754119743585,0.015264549606979788,0.9692380475690741,0.9912224650673576,0.008257550803198621,-0.023007923366737057,0.6747048994136493,0.43885763656180254,0.06907305219904243,0.008352110956905313,0.9707770876621326,0.9904801356375262,0.008616523910566483,0.0919029331835356,-0.00036859675780506176,0.0012497850515420517,0.0009433706826755149,0.002782662506277944,0.08210424720023082,0.8718535889226373,0.0028498181766536705,0.018514305453070142,0.31947659421915603,0.4345240429951432,0.03299584934691898,0.023290620768394544,1.1036921437629816,0.9939191264997396,0.00781583698145861,0.08312306312755505,0.34358272766781456,0.4303946701511167,0.03578532556277312,0.02032359581562811,0.9782687053431408,0.9954490754649108,0.004269655492804524,0.07859353847668787,0.3992083103283873,0.3265776112286144,0.051900346280059566,0.014370105107146662,0.8811361735859135,0.9932447881217922,0.006578917743488375,-0.04764231750678784
# 0,10.0,0.4825251594857349,0.3857327845174428,0.05512840650241081,0.020260452884830832,1.3409167119734908,0.934040840619822,0.03226090230167143,0.3071400256447004,0.6672384057116422,0.34099270040299545,0.08397957880664553,0.015198562039949737,1.3414982140710383,0.968306314760518,0.02197304128434625,0.13584469646622274,0.001536803483305677,0.036647773849217136,0.0007133574055865633,-0.0012059280405273779,0.030585733812755693,0.6959311465322393,0.001830382355212248,-0.027900329600699277,0.33567617034023606,0.3419726100730769,0.04215673030711989,0.02656989059845946,1.5322153063633714,0.8716048685150017,0.053241996653172974,0.20280523446363125,0.3401337264349824,0.3199176189211241,0.0448984617800832,0.02593271555730734,1.0977944152539263,0.9917611053066672,0.0064587182195425434,0.042289446521191716,0.4544464845900953,0.4541665920593218,0.04510506226226334,0.019465914154405285,1.2460817299266165,0.9398322602217952,0.028544555820146224,0.3351070447764733

# %%
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]

#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
#resultadoDatos= pd.concat(datostotal)

# %%
datos1=pd.read_csv('prueba.csv',decimal=",", encoding='utf-8',sep=u',')

# %%
datos1
# Out:
#     Unnamed: 0 Pruebas     coef(a)_6am-MLP     rsquared_6am-MLP  \
# 0            0     1.0  0.3649065512490399   0.3897614421175062
# 1            0     2.0  0.5134709035385809   0.4151113004995016
# 2            0     3.0  0.6029450222655992   0.4552307239383474
# 3            0     4.0  0.4392827471871187   0.2926406794018279
# 4            0     5.0  0.3304023214292526   0.3752359152166953
# 5            0     6.0  0.4121364748872941    0.446190741652399
# 6            0     7.0  0.6475989799535233   0.5275131757258892
# 7            0     8.0  0.4618114858778268   0.3747603497558605
# 8            0     9.0  0.2431281776947499  0.28307739026682743
# 9            0    10.0  0.4449333222821231  0.32877240491096194
# 10           0    10.0  0.4825251594857349   0.3857327845174428
#
#    Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0     0.04133825185568762  0.017609918690071016  0.9899460704564588
# 1     0.05518108544668105  0.018376335113421054  1.1975262733420031
# 2     0.05971567442715505  0.022844419255337804   1.392693978281973
# 3    0.061832512420736924   0.02497083857404957  1.3427081738814446
# 4    0.038598372043825435  0.018862290456259048  0.9931037385436088
# 5     0.04157008861009052  0.017723405599392623  0.9588549963315194
# 6     0.05548868554758156  0.015707933646817114  1.1771915503815036
# 7     0.05400465909998044  0.019195509821561846  1.2937823208009172
# 8     0.03502990261711806  0.014876213546214878  0.6453799132251243
# 9     0.05755754119743585  0.015264549606979788  0.9692380475690741
# 10    0.05512840650241081  0.020260452884830832  1.3409167119734908
#
#    rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP    coef(b)_Acu-6am-MLP  \
# 0    0.9667606342674128       0.016618755823697838     0.3575594820816234
# 1    0.9729030893385012        0.01809381868621007     0.1233457592797906
# 2    0.9545593206802264        0.02751038888007313   -0.12446739661299758
# 3    0.9870973712846348       0.013898272379473914    -0.1274352546880681
# 4    0.9872645822676523         0.0102118521670477   -0.05736949909686946
# 5      0.98195591627919       0.011767777262349788   -0.21559481268523112
# 6    0.9894438000921388       0.011008431859591156    0.16839370824430916
# 7    0.9877621609760316       0.013037894769508795    -0.2831952070249109
# 8    0.9839151475080772      0.0074707679732546155    0.21692922942223333
# 9    0.9912224650673576       0.008257550803198621  -0.023007923366737057
# 10    0.934040840619822        0.03226090230167143     0.3071400256447004
#
#     ... Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  \
# 0   ...         0.005334882577522506    0.07697326388979599
# 1   ...         0.004457555611756504     0.1724263620632126
# 2   ...          0.00518130672958422    -0.2362698236008851
# 3   ...         0.004553997107237891    0.15314622318480445
# 4   ...         0.007587252677291394     0.6111085492295196
# 5   ...         0.005845065446026582  -0.046924183842860866
# 6   ...         0.004858713965397032    0.17125196666371514
# 7   ...         0.005793600079304415    -0.2658754206837525
# 8   ...         0.005907714843042287   -0.25916312125415913
# 9   ...         0.004269655492804524    0.07859353847668787
# 10  ...        0.0064587182195425434   0.042289446521191716
#
#      coef(a)_6am-MLP-LM  rsquared_6am-MLP-LM Standard Error_6am-MLP-LM  \
# 0   0.35808074465091444   0.4995120620615416       0.03245076182211084
# 1    0.4828906568611232   0.4553301444622701       0.04781590000382572
# 2    0.5279033711793427   0.4749581461059963       0.05025089585064562
# 3    0.3406539653452447  0.26231956512610444       0.05171925820819143
# 4    0.3805408805104692   0.4525906242845946       0.03789001181908547
# 5   0.36096790760420217   0.4565278435794189      0.035656907546016144
# 6    0.3983408849845003   0.5446135049811287      0.032977734670087966
# 7    0.4283449169442318  0.26066463478504753       0.06531205708969537
# 8    0.3308372902352297  0.14980734546660798       0.07135536575718149
# 9    0.3992083103283873   0.3265776112286144      0.051900346280059566
# 10   0.4544464845900953   0.4541665920593218       0.04510506226226334
#
#       coef(b)_6am-MLP-LM coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0   0.015182437998358932     0.8598239688803573      0.9714045972809758
# 1   0.018574305679674698     1.1210614209599783      0.9806473038643702
# 2   0.021544802661521832     1.3031733413236888      0.9568719031007096
# 3   0.022865335614578677     1.1585609826454957      0.9868924385302316
# 4   0.018056877317830976      1.037591178265014      0.9891739721210048
# 5    0.01631244500687257     0.8594589875848374      0.9808361188918542
# 6     0.0155544181493038     0.9331011017994972       0.982710759418296
# 7   0.019260622208696256      1.350130476659804      0.9800401245791709
# 8   0.021735405719435368     0.8682119285751235       0.976690905012162
# 9   0.014370105107146662     0.8811361735859135      0.9932447881217922
# 10  0.019465914154405285     1.2460817299266165      0.9398322602217952
#
#    Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0            0.01335603856955662     0.3377343861206118
# 1           0.014258170757486966    0.16788915969760693
# 2           0.025048142019355138   -0.14237791718504827
# 3           0.012088294259295734   -0.08667562424356284
# 4           0.009827534680931851   -0.11888947656926648
# 5           0.010876489644693343   -0.13667404230272373
# 6            0.01120531039498603     0.2058194563865765
# 7           0.017444270393107173    -0.5075636235162657
# 8            0.01214311110070748    0.14308363138198188
# 9           0.006578917743488375   -0.04764231750678784
# 10          0.028544555820146224     0.3351070447764733
#
# [11 rows x 50 columns]

# %%
pwd
# Out:
# '/root/notebooks/resultados-31-01'

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
#3cp -r /root/notebooks/prueba.csv /root/notebooks/resultados-modelos-tesis

# %%
#cd resultados-modelos-tesis

# %%
# !git config user.email "rodrigo.montenegro@alumnos.uv.cl"

# !git config user.name "Rodrigomontenegrofarias"

# %%
# !git add .

# %%
# !git commit -m "a"
# Out:
# [main 9862c2e] a
#  1 file changed, 1 insertion(+)

# %%
# !git push origin main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 781 bytes | 781.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:Rodrigomontenegrofarias/resultados-31-01.git
#    6752f53..9862c2e  main -> main

# %% [markdown]
# #
