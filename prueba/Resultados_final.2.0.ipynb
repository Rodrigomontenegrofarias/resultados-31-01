# %%
! rm -rf resultados-31-01 resultados-modelos-tesis

# %%
from getpass import getpass
import os

os.environ['USER'] = "Rodrigomontenegrofarias"
os.environ['PASSWORD'] = getpass('Enter the password of your Github account: ')
os.environ['REPOSITORY'] = "resultados-31-01"
os.environ['GITHUB_AUTH'] = os.environ['USER'] + ':' + os.environ['PASSWORD']

# !rm -rf $REPOSITORY # To remove the previous clone of the Github repository
# !git clone https://$GITHUB_AUTH@github.com/$USER/$REPOSITORY.git 

os.environ['USER'] = os.environ['PASSWORD'] = os.environ['REPOSITORY'] = os.environ['GITHUB_AUTH'] = ""


# ingresos de bases de datos guarddadas mediante git
# Out:
# Enter the password of your Github account: ········
# Cloning into 'resultados-31-01'...
# remote: Enumerating objects: 320, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 320 (delta 35), reused 30 (delta 11), pack-reused 266
# Receiving objects: 100% (320/320), 47.81 MiB | 20.17 MiB/s, done.
# Resolving deltas: 100% (204/204), done.

# %%
cd resultados-31-01/
# Out:
# /root/notebooks/resultados-31-01

# %%
#cargamos librerias
import pandas as pd
import numpy as np
#graficas
import matplotlib.pylab as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,9)
plt.style.use('fast')
#ver redes neuronales

#sklear para ver modelos machine learning
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

import matplotlib.pyplot as plt
# plt.xkcd()
# plt.style.use('ggplot')
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (20, 8)

# %% [markdown]
# # Ingreso de bases de datos y coneccion a drive.

# %%
# !git config user.email "rodrigo.montenegro@alumnos.uv.cl"

# !git config user.name "Rodrigomontenegrofarias"

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
# solo el primer se encuentra en kl/h se debe cambiar a m/S

##Imprlementar desde github:

datos1=pd.read_csv('Prueba1.0.csv',decimal=",", encoding='utf-8',sep=u',')
datos2=pd.read_csv('Prueba2.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos3=pd.read_csv('Prueba3.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos4=pd.read_csv('Prueba4.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos5=pd.read_csv('Prueba5.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos6=pd.read_csv('Prueba6.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos7=pd.read_csv('Prueba7.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
datos8=pd.read_csv('Prueba8.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos9=pd.read_csv('Prueba9.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos10=pd.read_csv('Prueba10.0.csv',decimal=",",sep=u',', encoding='utf-8',dayfirst=True)

#datos11=pd.read_csv('/content/Rodrigomontenegrofarias/resultados/Prueba11.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos12=pd.read_csv('/content/Rodrigomontenegrofarias/resultados/Prueba12.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#datos13=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba13.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos14=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba14.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos15=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba15.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos16=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba16.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos17=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba17.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos18=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba18.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#datos19=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba19.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos20=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba20.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#Fecha
#datos1 = datos1.rename(columns={'Gust(km/h)':'Gust(m/s)'})
#datos1 = datos1.rename(columns={'Wind Speed(km/h)':'Wind Speed(m/s)'})


#df.columns
#Gust(km/h)
 
datos1
# Out:
#    Unnamed: 0 Pruebas     coef(a)_6am-MLP    rsquared_6am-MLP  \
# 0           0     1.0  0.5015981156397032  0.3879044477735464
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0    0.05704573898201479  0.023559538775312333   1.256095299620943
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP  coef(b)_Acu-6am-MLP  ...  \
# 0   0.9740651506547231       0.018556263707775925  0.09459746563768029  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  coef(a)_6am-MLP-LM  \
# 0         0.002994581822451683  -0.050410850190506826  0.4998604921589266
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.33973966331979044       0.06308896525216824  0.020567673546435208
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     1.0968113050138868      0.9644591979815889
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0           0.01906222906974971    0.16953657078595658
#
# [1 rows x 50 columns]

# %%
print(datos1)
# Out:
#    Unnamed: 0 Pruebas     coef(a)_6am-MLP    rsquared_6am-MLP  \
# 0           0     1.0  0.5015981156397032  0.3879044477735464
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0    0.05704573898201479  0.023559538775312333   1.256095299620943
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP  coef(b)_Acu-6am-MLP  ...  \
# 0   0.9740651506547231       0.018556263707775925  0.09459746563768029  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  coef(a)_6am-MLP-LM  \
# 0         0.002994581822451683  -0.050410850190506826  0.4998604921589266
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.33973966331979044       0.06308896525216824  0.020567673546435208
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     1.0968113050138868      0.9644591979815889
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0           0.01906222906974971    0.16953657078595658
#
# [1 rows x 50 columns]

# %%
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,]
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
resultadoDatos= pd.concat(datostotal)

# %%
resultadoDatos
# Out:
#    Unnamed: 0 Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP  \
# 0           0     1.0   0.5015981156397032   0.3879044477735464
# 0           0     2.0  0.36759777153857853   0.5113886824763468
# 0           0     3.0   0.5437184818738081  0.36657613999565786
# 0           0     4.0   0.4914354331736572  0.27772741499059406
# 0           0     5.0  0.38689484282170294   0.5095783216384939
# 0           0     6.0  0.36778124857068767    0.603071668449968
# 0           0     7.0   0.4852319871066285  0.48379907637545383
# 0           0     8.0   0.3355553975233708  0.35200175750000284
# 0           0     9.0   0.6120214113522476   0.3928503346889768
# 0           0    10.0  0.44282480082111886   0.3233166560455685
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0    0.05704573898201479  0.023559538775312333   1.256095299620943
# 0    0.03253113223332392  0.016954192946870027  0.8094689221893592
# 0     0.0647081985970468  0.027632007901893737  1.4191473206065497
# 0    0.07175095858157203  0.023397954746053877  1.6643693026290252
# 0    0.03436310511965039  0.017444350630862818  0.8918218908477642
# 0   0.027013523995800648  0.017105067019369084   0.889057680720504
# 0    0.04537810928395519  0.019062450722977606  1.0748613102879547
# 0    0.04121912899995989  0.019911738709332678  0.8627193579314258
# 0    0.06888442208534368  0.019662850695231496  1.5691794625004003
# 0   0.058000360070863594  0.021454373320384253  1.0921786698135776
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP    coef(b)_Acu-6am-MLP  ...  \
# 0   0.9740651506547231       0.018556263707775925    0.09459746563768029  ...
# 0   0.9113202051572921       0.022861098927337644       0.65165296805736  ...
# 0   0.9589529141960387       0.026582149080628305      0.717877079969288  ...
# 0   0.9495327848856361       0.034739172345560974    -0.1345804218402215  ...
# 0   0.9919364980731578      0.0072797778514442635     0.1271730370416586  ...
# 0   0.9755828388765545       0.012734020139393162     -0.303421352512325  ...
# 0   0.9837052568789612       0.012524597454946147    0.03112611978254299  ...
# 0   0.9811235506299238       0.010833977612102289  -0.014284461483399312  ...
# 0   0.9755935443972689       0.022470389346101127   -0.04130902184354045  ...
# 0   0.9894569596714587        0.01020700329295571     0.3155911073991662  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0         0.002994581822451683  -0.050410850190506826   0.4998604921589266
# 0        0.0051377015126917855    0.14810530967614274  0.34323404727393664
# 0         0.004884006053199816  -0.040873723577222854   0.5845741617553839
# 0         0.004558628639144864    0.24372985362541605   0.4125597353222788
# 0         0.005146426499902712    0.12399439780880038   0.3955427218650996
# 0         0.005856256828408338   -0.14413735345608022   0.3701493224153318
# 0         0.007694999770483717    -0.2801768850444152  0.39026169853187587
# 0         0.005597085512245847   -0.23025103686873802  0.34956294067911614
# 0         0.004882089252432355   0.042769299640985026   0.5292343915892774
# 0         0.004710968465890543     -0.552344901836262   0.4387009031538875
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.33973966331979044       0.06308896525216824  0.020567673546435208
# 0   0.5304827233773406      0.029234831565934653  0.015696588070019418
# 0   0.3725454640040473       0.06868488968489446  0.025865725975170194
# 0  0.19838168591424343       0.07508270451189736  0.022286838911838018
# 0   0.5677240280986771      0.031248226886952085  0.016469502136769627
# 0   0.5601146976693563      0.029698074896072537   0.01777104686829336
# 0   0.4805474189758021       0.03673506571282354   0.01864521141236873
# 0   0.3940114740170596       0.03924851580509269  0.017347238942526235
# 0   0.2607848137547554       0.08067007421928642   0.01926867226987684
# 0   0.3269112914977176       0.05699146757811209   0.02063132319592475
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     1.0968113050138868      0.9644591979815889
# 0      0.754953528478872      0.9157567654212787
# 0     1.4204914815145826      0.9654915978044565
# 0     1.5142366511345842       0.943423494438171
# 0     0.8854942001429006       0.993238378077631
# 0     0.9048313617291857      0.9725622366826008
# 0     0.9412699076435931      0.9783346174291134
# 0     0.8180769770515626      0.9807971392519738
# 0     1.5205846966814083      0.9727150630834693
# 0     1.0678176853585046      0.9912151987681157
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0           0.01906222906974971    0.16953657078595658
# 0           0.02073088051922466     0.5660548341297056
# 0          0.024313467281912884      0.583969746101678
# 0           0.03357210354924023   -0.08816810100346811
# 0          0.006614613924431304    0.11584585230078631
# 0          0.013759523075430413     -0.290770130586565
# 0          0.012681590603989592    0.11669494604701068
# 0          0.010363528020194832   -0.10159684281699508
# 0           0.02305681724624414   -0.12823356338166692
# 0          0.009101211128668685    0.24003351843391824
#
# [10 rows x 50 columns]

# %%
#resultadoDatos['Pruebas'] = resultadoDatos['Pruebas'].astype('float')
#resultadoDatos = resultadoDatos.set_index('Pruebas')

# %%
resultadoDatos
# Out:
#    Unnamed: 0 Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP  \
# 0           0     1.0   0.5015981156397032   0.3879044477735464
# 0           0     2.0  0.36759777153857853   0.5113886824763468
# 0           0     3.0   0.5437184818738081  0.36657613999565786
# 0           0     4.0   0.4914354331736572  0.27772741499059406
# 0           0     5.0  0.38689484282170294   0.5095783216384939
# 0           0     6.0  0.36778124857068767    0.603071668449968
# 0           0     7.0   0.4852319871066285  0.48379907637545383
# 0           0     8.0   0.3355553975233708  0.35200175750000284
# 0           0     9.0   0.6120214113522476   0.3928503346889768
# 0           0    10.0  0.44282480082111886   0.3233166560455685
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0    0.05704573898201479  0.023559538775312333   1.256095299620943
# 0    0.03253113223332392  0.016954192946870027  0.8094689221893592
# 0     0.0647081985970468  0.027632007901893737  1.4191473206065497
# 0    0.07175095858157203  0.023397954746053877  1.6643693026290252
# 0    0.03436310511965039  0.017444350630862818  0.8918218908477642
# 0   0.027013523995800648  0.017105067019369084   0.889057680720504
# 0    0.04537810928395519  0.019062450722977606  1.0748613102879547
# 0    0.04121912899995989  0.019911738709332678  0.8627193579314258
# 0    0.06888442208534368  0.019662850695231496  1.5691794625004003
# 0   0.058000360070863594  0.021454373320384253  1.0921786698135776
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP    coef(b)_Acu-6am-MLP  ...  \
# 0   0.9740651506547231       0.018556263707775925    0.09459746563768029  ...
# 0   0.9113202051572921       0.022861098927337644       0.65165296805736  ...
# 0   0.9589529141960387       0.026582149080628305      0.717877079969288  ...
# 0   0.9495327848856361       0.034739172345560974    -0.1345804218402215  ...
# 0   0.9919364980731578      0.0072797778514442635     0.1271730370416586  ...
# 0   0.9755828388765545       0.012734020139393162     -0.303421352512325  ...
# 0   0.9837052568789612       0.012524597454946147    0.03112611978254299  ...
# 0   0.9811235506299238       0.010833977612102289  -0.014284461483399312  ...
# 0   0.9755935443972689       0.022470389346101127   -0.04130902184354045  ...
# 0   0.9894569596714587        0.01020700329295571     0.3155911073991662  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0         0.002994581822451683  -0.050410850190506826   0.4998604921589266
# 0        0.0051377015126917855    0.14810530967614274  0.34323404727393664
# 0         0.004884006053199816  -0.040873723577222854   0.5845741617553839
# 0         0.004558628639144864    0.24372985362541605   0.4125597353222788
# 0         0.005146426499902712    0.12399439780880038   0.3955427218650996
# 0         0.005856256828408338   -0.14413735345608022   0.3701493224153318
# 0         0.007694999770483717    -0.2801768850444152  0.39026169853187587
# 0         0.005597085512245847   -0.23025103686873802  0.34956294067911614
# 0         0.004882089252432355   0.042769299640985026   0.5292343915892774
# 0         0.004710968465890543     -0.552344901836262   0.4387009031538875
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.33973966331979044       0.06308896525216824  0.020567673546435208
# 0   0.5304827233773406      0.029234831565934653  0.015696588070019418
# 0   0.3725454640040473       0.06868488968489446  0.025865725975170194
# 0  0.19838168591424343       0.07508270451189736  0.022286838911838018
# 0   0.5677240280986771      0.031248226886952085  0.016469502136769627
# 0   0.5601146976693563      0.029698074896072537   0.01777104686829336
# 0   0.4805474189758021       0.03673506571282354   0.01864521141236873
# 0   0.3940114740170596       0.03924851580509269  0.017347238942526235
# 0   0.2607848137547554       0.08067007421928642   0.01926867226987684
# 0   0.3269112914977176       0.05699146757811209   0.02063132319592475
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     1.0968113050138868      0.9644591979815889
# 0      0.754953528478872      0.9157567654212787
# 0     1.4204914815145826      0.9654915978044565
# 0     1.5142366511345842       0.943423494438171
# 0     0.8854942001429006       0.993238378077631
# 0     0.9048313617291857      0.9725622366826008
# 0     0.9412699076435931      0.9783346174291134
# 0     0.8180769770515626      0.9807971392519738
# 0     1.5205846966814083      0.9727150630834693
# 0     1.0678176853585046      0.9912151987681157
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0           0.01906222906974971    0.16953657078595658
# 0           0.02073088051922466     0.5660548341297056
# 0          0.024313467281912884      0.583969746101678
# 0           0.03357210354924023   -0.08816810100346811
# 0          0.006614613924431304    0.11584585230078631
# 0          0.013759523075430413     -0.290770130586565
# 0          0.012681590603989592    0.11669494604701068
# 0          0.010363528020194832   -0.10159684281699508
# 0           0.02305681724624414   -0.12823356338166692
# 0          0.009101211128668685    0.24003351843391824
#
# [10 rows x 50 columns]

# %%
resultadoDatos = resultadoDatos.drop(['Unnamed: 0'], axis=1)

# %%
resultadoDatos
# Out:
#   Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP Standard Error_6am-MLP  \
# 0     1.0   0.5015981156397032   0.3879044477735464    0.05704573898201479
# 0     2.0  0.36759777153857853   0.5113886824763468    0.03253113223332392
# 0     3.0   0.5437184818738081  0.36657613999565786     0.0647081985970468
# 0     4.0   0.4914354331736572  0.27772741499059406    0.07175095858157203
# 0     5.0  0.38689484282170294   0.5095783216384939    0.03436310511965039
# 0     6.0  0.36778124857068767    0.603071668449968   0.027013523995800648
# 0     7.0   0.4852319871066285  0.48379907637545383    0.04537810928395519
# 0     8.0   0.3355553975233708  0.35200175750000284    0.04121912899995989
# 0     9.0   0.6120214113522476   0.3928503346889768    0.06888442208534368
# 0    10.0  0.44282480082111886   0.3233166560455685   0.058000360070863594
#
#         coef(b)_6am-MLP coef(a)_Acu-6am-MLP rsquared_Acu-6am-MLP  \
# 0  0.023559538775312333   1.256095299620943   0.9740651506547231
# 0  0.016954192946870027  0.8094689221893592   0.9113202051572921
# 0  0.027632007901893737  1.4191473206065497   0.9589529141960387
# 0  0.023397954746053877  1.6643693026290252   0.9495327848856361
# 0  0.017444350630862818  0.8918218908477642   0.9919364980731578
# 0  0.017105067019369084   0.889057680720504   0.9755828388765545
# 0  0.019062450722977606  1.0748613102879547   0.9837052568789612
# 0  0.019911738709332678  0.8627193579314258   0.9811235506299238
# 0  0.019662850695231496  1.5691794625004003   0.9755935443972689
# 0  0.021454373320384253  1.0921786698135776   0.9894569596714587
#
#   Standard Error_Acu-6am-MLP    coef(b)_Acu-6am-MLP coef(a)_6am-Beysens  ...  \
# 0       0.018556263707775925    0.09459746563768029  0.5598749518941102  ...
# 0       0.022861098927337644       0.65165296805736  0.6838734008685707  ...
# 0       0.026582149080628305      0.717877079969288  0.7823661806525462  ...
# 0       0.034739172345560974    -0.1345804218402215  0.7371392758670527  ...
# 0      0.0072797778514442635     0.1271730370416586   0.828843704154858  ...
# 0       0.012734020139393162     -0.303421352512325  0.6378843065899643  ...
# 0       0.012524597454946147    0.03112611978254299  0.5617571645069621  ...
# 0       0.010833977612102289  -0.014284461483399312  0.5635077327217879  ...
# 0       0.022470389346101127   -0.04130902184354045   0.695353106958234  ...
# 0        0.01020700329295571     0.3155911073991662  0.6421707464836138  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0         0.002994581822451683  -0.050410850190506826   0.4998604921589266
# 0        0.0051377015126917855    0.14810530967614274  0.34323404727393664
# 0         0.004884006053199816  -0.040873723577222854   0.5845741617553839
# 0         0.004558628639144864    0.24372985362541605   0.4125597353222788
# 0         0.005146426499902712    0.12399439780880038   0.3955427218650996
# 0         0.005856256828408338   -0.14413735345608022   0.3701493224153318
# 0         0.007694999770483717    -0.2801768850444152  0.39026169853187587
# 0         0.005597085512245847   -0.23025103686873802  0.34956294067911614
# 0         0.004882089252432355   0.042769299640985026   0.5292343915892774
# 0         0.004710968465890543     -0.552344901836262   0.4387009031538875
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.33973966331979044       0.06308896525216824  0.020567673546435208
# 0   0.5304827233773406      0.029234831565934653  0.015696588070019418
# 0   0.3725454640040473       0.06868488968489446  0.025865725975170194
# 0  0.19838168591424343       0.07508270451189736  0.022286838911838018
# 0   0.5677240280986771      0.031248226886952085  0.016469502136769627
# 0   0.5601146976693563      0.029698074896072537   0.01777104686829336
# 0   0.4805474189758021       0.03673506571282354   0.01864521141236873
# 0   0.3940114740170596       0.03924851580509269  0.017347238942526235
# 0   0.2607848137547554       0.08067007421928642   0.01926867226987684
# 0   0.3269112914977176       0.05699146757811209   0.02063132319592475
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     1.0968113050138868      0.9644591979815889
# 0      0.754953528478872      0.9157567654212787
# 0     1.4204914815145826      0.9654915978044565
# 0     1.5142366511345842       0.943423494438171
# 0     0.8854942001429006       0.993238378077631
# 0     0.9048313617291857      0.9725622366826008
# 0     0.9412699076435931      0.9783346174291134
# 0     0.8180769770515626      0.9807971392519738
# 0     1.5205846966814083      0.9727150630834693
# 0     1.0678176853585046      0.9912151987681157
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0           0.01906222906974971    0.16953657078595658
# 0           0.02073088051922466     0.5660548341297056
# 0          0.024313467281912884      0.583969746101678
# 0           0.03357210354924023   -0.08816810100346811
# 0          0.006614613924431304    0.11584585230078631
# 0          0.013759523075430413     -0.290770130586565
# 0          0.012681590603989592    0.11669494604701068
# 0          0.010363528020194832   -0.10159684281699508
# 0           0.02305681724624414   -0.12823356338166692
# 0          0.009101211128668685    0.24003351843391824
#
# [10 rows x 49 columns]

# %%
resultadoDatos=resultadoDatos.astype(float)

# %%
resultadoDatos
# Out:
#    Pruebas  coef(a)_6am-MLP  rsquared_6am-MLP  Standard Error_6am-MLP  \
# 0      1.0         0.501598          0.387904                0.057046
# 0      2.0         0.367598          0.511389                0.032531
# 0      3.0         0.543718          0.366576                0.064708
# 0      4.0         0.491435          0.277727                0.071751
# 0      5.0         0.386895          0.509578                0.034363
# 0      6.0         0.367781          0.603072                0.027014
# 0      7.0         0.485232          0.483799                0.045378
# 0      8.0         0.335555          0.352002                0.041219
# 0      9.0         0.612021          0.392850                0.068884
# 0     10.0         0.442825          0.323317                0.058000
#
#    coef(b)_6am-MLP  coef(a)_Acu-6am-MLP  rsquared_Acu-6am-MLP  \
# 0         0.023560             1.256095              0.974065
# 0         0.016954             0.809469              0.911320
# 0         0.027632             1.419147              0.958953
# 0         0.023398             1.664369              0.949533
# 0         0.017444             0.891822              0.991936
# 0         0.017105             0.889058              0.975583
# 0         0.019062             1.074861              0.983705
# 0         0.019912             0.862719              0.981124
# 0         0.019663             1.569179              0.975594
# 0         0.021454             1.092179              0.989457
#
#    Standard Error_Acu-6am-MLP  coef(b)_Acu-6am-MLP  coef(a)_6am-Beysens  ...  \
# 0                    0.018556             0.094597             0.559875  ...
# 0                    0.022861             0.651653             0.683873  ...
# 0                    0.026582             0.717877             0.782366  ...
# 0                    0.034739            -0.134580             0.737139  ...
# 0                    0.007280             0.127173             0.828844  ...
# 0                    0.012734            -0.303421             0.637884  ...
# 0                    0.012525             0.031126             0.561757  ...
# 0                    0.010834            -0.014284             0.563508  ...
# 0                    0.022470            -0.041309             0.695353  ...
# 0                    0.010207             0.315591             0.642171  ...
#
#    Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  coef(a)_6am-MLP-LM  \
# 0                      0.002995              -0.050411            0.499860
# 0                      0.005138               0.148105            0.343234
# 0                      0.004884              -0.040874            0.584574
# 0                      0.004559               0.243730            0.412560
# 0                      0.005146               0.123994            0.395543
# 0                      0.005856              -0.144137            0.370149
# 0                      0.007695              -0.280177            0.390262
# 0                      0.005597              -0.230251            0.349563
# 0                      0.004882               0.042769            0.529234
# 0                      0.004711              -0.552345            0.438701
#
#    rsquared_6am-MLP-LM  Standard Error_6am-MLP-LM  coef(b)_6am-MLP-LM  \
# 0             0.339740                   0.063089            0.020568
# 0             0.530483                   0.029235            0.015697
# 0             0.372545                   0.068685            0.025866
# 0             0.198382                   0.075083            0.022287
# 0             0.567724                   0.031248            0.016470
# 0             0.560115                   0.029698            0.017771
# 0             0.480547                   0.036735            0.018645
# 0             0.394011                   0.039249            0.017347
# 0             0.260785                   0.080670            0.019269
# 0             0.326911                   0.056991            0.020631
#
#    coef(a)_Acu-6am-MLP-LM  rsquared_Acu-6am-MLP-LM  \
# 0                1.096811                 0.964459
# 0                0.754954                 0.915757
# 0                1.420491                 0.965492
# 0                1.514237                 0.943423
# 0                0.885494                 0.993238
# 0                0.904831                 0.972562
# 0                0.941270                 0.978335
# 0                0.818077                 0.980797
# 0                1.520585                 0.972715
# 0                1.067818                 0.991215
#
#    Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0                       0.019062                0.169537
# 0                       0.020731                0.566055
# 0                       0.024313                0.583970
# 0                       0.033572               -0.088168
# 0                       0.006615                0.115846
# 0                       0.013760               -0.290770
# 0                       0.012682                0.116695
# 0                       0.010364               -0.101597
# 0                       0.023057               -0.128234
# 0                       0.009101                0.240034
#
# [10 rows x 49 columns]

# %%
#mean_df = df['R-cuadrado-Modelo-Beysens(6am)'].mean()
#print(mean_df)

# %% [markdown]
# # Resultados de Pruebas a modelo test ADAMAX

# %%
import matplotlib.pyplot as plt

# %%
#Graficos

# %% [markdown]
# ## grafico 1, modelo R cuadrado

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo MLP 6AM")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
mean_df1 = resultadoDatos['rsquared_6am-Beysens'].mean()
print(mean_df1)
# Out:
# 0.37016811888526013

# %%
mean_df = resultadoDatos['rsquared_6am-MLP'].mean()
print(mean_df)
# Out:
# 0.42082144999346094

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-MLP']))
# Out:
# 0.12075401821004374
# 0.10153775059901696

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP 6AM")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df111 = resultadoDatos['coef(a)_6am-Beysens'].mean()
print(mean_df111)
# Out:
# 0.66927705706977

# %%
mean_df = resultadoDatos['coef(a)_6am-MLP'].mean()
print(mean_df)
# Out:
# 0.4534659490421503

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-MLP']))
# Out:
# 0.09439027365604008
# 0.08895434462739697

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP 6AM")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df1145 = resultadoDatos['coef(b)_6am-Beysens'].mean()
print(mean_df1145)
# Out:
# 0.014966678583845625

# %%
mean_df1245 = resultadoDatos['coef(b)_6am-MLP'].mean()
print(mean_df1245)
# Out:
# 0.02061845254682879

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-MLP']))
# Out:
# 0.004049936200663399
# 0.0034309652547416416

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP 6AM")
plt.ylabel('Resultados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df114 = resultadoDatos['Standard Error_6am-Beysens'].mean()
print(mean_df114)
# Out:
# 0.08081945857865142

# %%
mean_df124 = resultadoDatos['Standard Error_6am-MLP'].mean()
print(mean_df124)
# Out:
# 0.05008946779495309

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-MLP']))
# Out:
# 0.016237330032846314
# 0.01611121875463878

# %% [markdown]
# ## grafico 2

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo Acumulado MLP 6AM")
plt.ylabel('Resultados acumulados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-Beysens'].mean()
print(mean_df11)
# Out:
# 0.9712494761888391

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-MLP'].mean()
print(mean_df11)
# Out:
# 0.9691269703421016

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-MLP']))
# Out:
# 0.018894626158003587
# 0.02409927030947184

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP 6AM")
plt.ylabel('Resultados acumulados de pendient')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11112 = resultadoDatos['coef(a)_Acu-6am-Beysens'].mean()
print(mean_df11112)
# Out:
# 1.1705298815949823

# %%
mean_df11111 = resultadoDatos['coef(a)_Acu-6am-MLP'].mean()
print(mean_df11111)
# Out:
# 1.1528899217147504

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-MLP']))
# Out:
# 0.15010421843367172
# 0.31021994326608704

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP 6AM")
plt.ylabel('Resultados acumulados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df63 = resultadoDatos['coef(b)_Acu-6am-Beysens'].mean()
print(mean_df63)
# Out:
# 0.24208982311779564

# %%
mean_df64= resultadoDatos['coef(b)_Acu-6am-MLP'].mean()
print(mean_df64)
# Out:
# 0.14444225202082098

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-MLP']))
# Out:
# 0.34143737100241944
# 0.328149455028751

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas1= resultadoDatos['Pruebas']
resultados1={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-6am-MLP']}
ax.plot(pruebas1,resultados1['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas1,resultados1['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP 6AM")
plt.ylabel('Resultados acumulados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-Beysens'].mean()
print(mean_df6)
# Out:
# 0.01777418885700519

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-MLP'].mean()
print(mean_df6)
# Out:
# 0.017878844975824554

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Out:
# 0.008308808962028213
# 0.0029637469799736237

# %% [markdown]
# ## grafico 3

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo MLP PD")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['rsquared_Beysens-PM'].mean()
print(mean_df6)
# Out:
# 0.002033379990477402

# %%
mean_df7 = resultadoDatos['rsquared_MLP-PM'].mean()
print(mean_df7)
# Out:
# 0.2663349805543723

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_MLP-PM']))
# Out:
# 0.0029637469799736237
# 0.10588053270171036

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP PD")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df77 = resultadoDatos['coef(a)_Beysens-PM'].mean()
print(mean_df77)
# Out:
# -7.03127316369432e-06

# %%
mean_df78 = resultadoDatos['coef(a)_MLP-PM'].mean()
print(mean_df78)
# Out:
# 0.3081975567713157

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_MLP-PM']))
# Out:
# 0.0009806793909912692
# 0.040217050262518345

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP PD")
plt.ylabel('Resultados de coeficiente')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df781 = resultadoDatos['coef(b)_Beysens-PM'].mean()
print(mean_df781)
# Out:
# 0.003605794062622472

# %%
mean_df786 = resultadoDatos['coef(b)_MLP-PM'].mean()
print(mean_df786)
# Out:
# 0.024847677098521075

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_MLP-PM']))
# Out:
# 0.0016563395598854654
# 0.0043282473481882685

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP PD")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864 = resultadoDatos['Standard Error_Beysens-PM'].mean()
print(mean_df7864)
# Out:
# 0.00177349684197417

# %%
mean_df7865 = resultadoDatos['Standard Error_MLP-PM'].mean()
print(mean_df7865)
# Out:
# 0.049287403461415615

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_MLP-PM']))
# Out:
# 0.0005049380390358262
# 0.01435319470107304

# %% [markdown]
# ## grafico 4

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo Acumulado MLP PD")
plt.ylabel('Resultados acumulados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df8 = resultadoDatos['rsquared_Acu-Beysens-PM'].mean()
print(mean_df8)
# Out:
# 0.7756849570403114

# %%
mean_df9 = resultadoDatos['rsquared_Acu-MLP-PM'].mean()
print(mean_df9)
# Out:
# 0.9693401448055381

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-MLP-PM']))
# Out:
# 0.10185658762366648
# 0.01972227845095452

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP PD")
plt.ylabel('Resultados acumulados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df78649 = resultadoDatos['coef(a)_Acu-Beysens-PM'].mean()
print(mean_df78649)
# Out:
# 0.12809518383875815

# %%
mean_df78648 = resultadoDatos['coef(a)_Acu-MLP-PM'].mean()
print(mean_df78648)
# Out:
# 1.2233409305454404

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-MLP-PM']))
# Out:
# 0.07128198366395737
# 0.3554972429765055

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP PD")
plt.ylabel('Resultados acumulados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Beysens-PM'].mean()
print(mean_df786489)
# Out:
# 0.005430765919729795

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-MLP-PM'].mean()
print(mean_df786489)
# Out:
# 0.0027688333132254717

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-MLP-PM']))
# Out:
# 0.05815878362530479
# 0.3825028135682858

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo de Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Acumulado Modelo MLP PD")
plt.ylabel('Resultados acumulados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864899 = resultadoDatos['Standard Error_Acu-Beysens-PM'].mean()
print(mean_df7864899)
# Out:
# 0.0056539241516667645

# %%
mean_df78648999 = resultadoDatos['Standard Error_Acu-MLP-PM'].mean()
print(mean_df78648999)
# Out:
# 0.019727782769612894

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-MLP-PM']))
# Out:
# 0.0022712280111849645
# 0.01109925040756666

# %%
#########################################################################################

# %% [markdown]
# # Resultados de Pruebas LM

# %%
import matplotlib.pyplot as plt

# %%
#Graficos

# %%
resultadoDatos
# Out:
#    Pruebas  coef(a)_6am-MLP  rsquared_6am-MLP  Standard Error_6am-MLP  \
# 0      1.0         0.501598          0.387904                0.057046
# 0      2.0         0.367598          0.511389                0.032531
# 0      3.0         0.543718          0.366576                0.064708
# 0      4.0         0.491435          0.277727                0.071751
# 0      5.0         0.386895          0.509578                0.034363
# 0      6.0         0.367781          0.603072                0.027014
# 0      7.0         0.485232          0.483799                0.045378
# 0      8.0         0.335555          0.352002                0.041219
# 0      9.0         0.612021          0.392850                0.068884
# 0     10.0         0.442825          0.323317                0.058000
#
#    coef(b)_6am-MLP  coef(a)_Acu-6am-MLP  rsquared_Acu-6am-MLP  \
# 0         0.023560             1.256095              0.974065
# 0         0.016954             0.809469              0.911320
# 0         0.027632             1.419147              0.958953
# 0         0.023398             1.664369              0.949533
# 0         0.017444             0.891822              0.991936
# 0         0.017105             0.889058              0.975583
# 0         0.019062             1.074861              0.983705
# 0         0.019912             0.862719              0.981124
# 0         0.019663             1.569179              0.975594
# 0         0.021454             1.092179              0.989457
#
#    Standard Error_Acu-6am-MLP  coef(b)_Acu-6am-MLP  coef(a)_6am-Beysens  ...  \
# 0                    0.018556             0.094597             0.559875  ...
# 0                    0.022861             0.651653             0.683873  ...
# 0                    0.026582             0.717877             0.782366  ...
# 0                    0.034739            -0.134580             0.737139  ...
# 0                    0.007280             0.127173             0.828844  ...
# 0                    0.012734            -0.303421             0.637884  ...
# 0                    0.012525             0.031126             0.561757  ...
# 0                    0.010834            -0.014284             0.563508  ...
# 0                    0.022470            -0.041309             0.695353  ...
# 0                    0.010207             0.315591             0.642171  ...
#
#    Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  coef(a)_6am-MLP-LM  \
# 0                      0.002995              -0.050411            0.499860
# 0                      0.005138               0.148105            0.343234
# 0                      0.004884              -0.040874            0.584574
# 0                      0.004559               0.243730            0.412560
# 0                      0.005146               0.123994            0.395543
# 0                      0.005856              -0.144137            0.370149
# 0                      0.007695              -0.280177            0.390262
# 0                      0.005597              -0.230251            0.349563
# 0                      0.004882               0.042769            0.529234
# 0                      0.004711              -0.552345            0.438701
#
#    rsquared_6am-MLP-LM  Standard Error_6am-MLP-LM  coef(b)_6am-MLP-LM  \
# 0             0.339740                   0.063089            0.020568
# 0             0.530483                   0.029235            0.015697
# 0             0.372545                   0.068685            0.025866
# 0             0.198382                   0.075083            0.022287
# 0             0.567724                   0.031248            0.016470
# 0             0.560115                   0.029698            0.017771
# 0             0.480547                   0.036735            0.018645
# 0             0.394011                   0.039249            0.017347
# 0             0.260785                   0.080670            0.019269
# 0             0.326911                   0.056991            0.020631
#
#    coef(a)_Acu-6am-MLP-LM  rsquared_Acu-6am-MLP-LM  \
# 0                1.096811                 0.964459
# 0                0.754954                 0.915757
# 0                1.420491                 0.965492
# 0                1.514237                 0.943423
# 0                0.885494                 0.993238
# 0                0.904831                 0.972562
# 0                0.941270                 0.978335
# 0                0.818077                 0.980797
# 0                1.520585                 0.972715
# 0                1.067818                 0.991215
#
#    Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0                       0.019062                0.169537
# 0                       0.020731                0.566055
# 0                       0.024313                0.583970
# 0                       0.033572               -0.088168
# 0                       0.006615                0.115846
# 0                       0.013760               -0.290770
# 0                       0.012682                0.116695
# 0                       0.010364               -0.101597
# 0                       0.023057               -0.128234
# 0                       0.009101                0.240034
#
# [10 rows x 49 columns]

# %% [markdown]
# ## grafico 1, modelo R cuadrado

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo MLP LM 6AM")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
mean_df1 = resultadoDatos['rsquared_6am-Beysens'].mean()
print(mean_df1)
# Out:
# 0.37016811888526013

# %%
mean_df = resultadoDatos['rsquared_6am-MLP-LM'].mean()
print(mean_df)
# Out:
# 0.40312432606287896

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-MLP-LM']))
# Out:
# 0.12075401821004374
# 0.12779226798692586

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP LM 6AM")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df111 = resultadoDatos['coef(a)_6am-Beysens'].mean()
print(mean_df111)
# Out:
# 0.66927705706977

# %%
mean_df = resultadoDatos['coef(a)_6am-MLP-LM'].mean()
print(mean_df)
# Out:
# 0.43136804147451147

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-MLP-LM']))
# Out:
# 0.09439027365604008
# 0.08119200069119953

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP LM 6AM")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df1145 = resultadoDatos['coef(b)_6am-Beysens'].mean()
print(mean_df1145)
# Out:
# 0.014966678583845625

# %%
mean_df1245 = resultadoDatos['coef(b)_6am-MLP-LM'].mean()
print(mean_df1245)
# Out:
# 0.01945498213292224

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-MLP-LM']))
# Out:
# 0.004049936200663399
# 0.003032164352808228

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP LM 6AM")
plt.ylabel('Resultados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df114 = resultadoDatos['Standard Error_6am-Beysens'].mean()
print(mean_df114)
# Out:
# 0.08081945857865142

# %%
mean_df124 = resultadoDatos['Standard Error_6am-MLP-LM'].mean()
print(mean_df124)
# Out:
# 0.05106828161132341

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-MLP-LM']))
# Out:
# 0.016237330032846314
# 0.020039550524405963

# %% [markdown]
# ## grafico 2

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo Acumulado MLP LM 6AM")
plt.ylabel('Resultados acumulado de R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-Beysens'].mean()
print(mean_df11)
# Out:
# 0.9712494761888391

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-MLP-LM'].mean()
print(mean_df11)
# Out:
# 0.9677993688938399

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-MLP-LM']))
# Out:
# 0.018894626158003587
# 0.02319321048324461

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP LM 6AM")
plt.ylabel('Resultados acumulados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11112 = resultadoDatos['coef(a)_Acu-6am-Beysens'].mean()
print(mean_df11112)
# Out:
# 1.1705298815949823

# %%
mean_df11111 = resultadoDatos['coef(a)_Acu-6am-MLP-LM'].mean()
print(mean_df11111)
# Out:
# 1.092456779474908

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-MLP-LM']))
# Out:
# 0.15010421843367172
# 0.290499872533067

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP LM 6AM")
plt.ylabel('Resultados acumulados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df63 = resultadoDatos['coef(b)_Acu-6am-Beysens'].mean()
print(mean_df63)
# Out:
# 0.24208982311779564

# %%
mean_df64= resultadoDatos['coef(b)_Acu-6am-MLP-LM'].mean()
print(mean_df64)
# Out:
# 0.11833668300103603

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-MLP-LM']))
# Out:
# 0.34143737100241944
# 0.2894221048581034

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas1= resultadoDatos['Pruebas']
resultados1={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-6am-MLP-LM']}
ax.plot(pruebas1,resultados1['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas1,resultados1['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP LM 6AM")
plt.ylabel('Resultados acumulados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-Beysens'].mean()
print(mean_df6)
# Out:
# 0.01777418885700519

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-MLP-LM'].mean()
print(mean_df6)
# Out:
# 0.017325596441908644

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-MLP-LM']))
# Out:
# 0.008308808962028213
# 0.008335718345111183

# %% [markdown]
# ## grafico 3

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo MLP LM PD")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['rsquared_Beysens-PM'].mean()
print(mean_df6)
# Out:
# 0.002033379990477402

# %%
mean_df7 = resultadoDatos['rsquared_Pd-MLP-LM'].mean()
print(mean_df7)
# Out:
# 0.24795923178681073

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Pd-MLP-LM']))
# Out:
# 0.0029637469799736237
# 0.08816137923588936

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP LM PD")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df77 = resultadoDatos['coef(a)_Beysens-PM'].mean()
print(mean_df77)
# Out:
# -7.03127316369432e-06

# %%
mean_df78 = resultadoDatos['coef(a)_Pd-MLP-LM'].mean()
print(mean_df78)
# Out:
# 0.3531170545969955

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Pd-MLP-LM']))
# Out:
# 0.0009806793909912692
# 0.07059563045001127

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP LM PD")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df781 = resultadoDatos['coef(b)_Beysens-PM'].mean()
print(mean_df781)
# Out:
# 0.003605794062622472

# %%
mean_df786 = resultadoDatos['coef(b)_Pd-MLP-LM'].mean()
print(mean_df786)
# Out:
# 0.022624924165317122

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Pd-MLP-LM']))
# Out:
# 0.0016563395598854654
# 0.003935380764854739

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP LM PD")
plt.ylabel('Resultados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864 = resultadoDatos['Standard Error_Beysens-PM'].mean()
print(mean_df7864)
# Out:
# 0.00177349684197417

# %%
mean_df7865 = resultadoDatos['Standard Error_Pd-MLP-LM'].mean()
print(mean_df7865)
# Out:
# 0.05838709674737521

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Pd-MLP-LM']))
# Out:
# 0.0005049380390358262
# 0.017638124655118968

# %% [markdown]
# ## grafico 4

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo Acumulado MLP LM PD")
plt.ylabel('Resultados acumulados de R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df8 = resultadoDatos['rsquared_Acu-Beysens-PM'].mean()
print(mean_df8)
# Out:
# 0.7756849570403114

# %%
mean_df9 = resultadoDatos['rsquared_Acu-Pd-MLP-LM'].mean()
print(mean_df9)
# Out:
# 0.9942979190593144

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Pd-MLP-LM']))
# Out:
# 0.10185658762366648
# 0.002451357924219826

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP LM PD")
plt.ylabel('Resultados acumulados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df78649 = resultadoDatos['coef(a)_Acu-Beysens-PM'].mean()
print(mean_df78649)
# Out:
# 0.12809518383875815

# %%
mean_df78648 = resultadoDatos['coef(a)_Acu-Pd-MLP-LM'].mean()
print(mean_df78648)
# Out:
# 1.0732227201914244

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Pd-MLP-LM']))
# Out:
# 0.07128198366395737
# 0.02881242943324077

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP LM PD")
plt.ylabel('Resultados acumulados de Coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Beysens-PM'].mean()
print(mean_df786489)
# Out:
# 0.005430765919729795

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Pd-MLP-LM'].mean()
print(mean_df786489)
# Out:
# -0.07395958902218809

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Pd-MLP-LM']))
# Out:
# 0.05815878362530479
# 0.23697867910030332

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo de Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Acumulado Modelo MLP LM PD")
plt.ylabel('Resultados acumulados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864899 = resultadoDatos['Standard Error_Acu-Beysens-PM'].mean()
print(mean_df7864899)
# Out:
# 0.0056539241516667645

# %%
mean_df78648999 = resultadoDatos['Standard Error_Acu-Pd-MLP-LM'].mean()
print(mean_df78648999)
# Out:
# 0.005146274435685166

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Pd-MLP-LM']))
# Out:
# 0.0022712280111849645
# 0.001178820430297382

# %% [markdown]
# ## Combinacion entre los modelos para tabla de conclusion.

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-Acumulado-MLP(6am)")
#ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="M Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="M Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="M Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
#cambiar 
#resultado6=pd.merge(df5, df6, on='Pruebas', suffixes=('_Beysens-PM', '_Acu-Beysens-PM'))

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-MLP-6am-LM")
plt.ylabel('Resultado R cuadrado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %% [markdown]
# resultados con modelo LM

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="M Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="M Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="M Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP'],'Modelo RNA(6am)1':resultadoDatos['rsquared_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = '^',label="Modelo-MLP(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)1'],c='red', marker = 'o',label="Modelo-MLP-6am-LM")
plt.ylabel('Resultado R cuadrado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
# Connect to the MySQL database
import pandas as pd
from sqlalchemy import create_engine
# Read CSV file into a DataFrame
#df = pd.read_csv("Prueba"+str(n)+".csv")
# Create a database engine
engine = create_engine('mysql+pymysql://root:sSeCr4t100114@24.199.124.40/demo')

# %%
from sqlalchemy import create_engine
import pandas as pd

# Create engine
engine = create_engine('mysql+pymysql://root:sSeCr4t100114@24.199.124.40/demo')

# Get data from engine
data = pd.read_sql_table('prueba', engine)

# Export data to CSV
data.to_csv('prueba.csv', index=False)

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
pwd
# Out:
# '/root/notebooks/resultados-31-01'

# %%
cat prueba.csv
# Out:
# Unnamed: 0,Pruebas,coef(a)_6am-MLP,rsquared_6am-MLP,Standard Error_6am-MLP,coef(b)_6am-MLP,coef(a)_Acu-6am-MLP,rsquared_Acu-6am-MLP,Standard Error_Acu-6am-MLP,coef(b)_Acu-6am-MLP,coef(a)_6am-Beysens,rsquared_6am-Beysens,Standard Error_6am-Beysens,coef(b)_6am-Beysens,coef(a)_Acu-6am-Beysens,rsquared_Acu-6am-Beysens,Standard Error_Acu-6am-Beysens,coef(b)_Acu-6am-Beysens,coef(a)_Beysens-PM,rsquared_Beysens-PM,Standard Error_Beysens-PM,coef(b)_Beysens-PM,coef(a)_Acu-Beysens-PM,rsquared_Acu-Beysens-PM,Standard Error_Acu-Beysens-PM,coef(b)_Acu-Beysens-PM,coef(a)_MLP-PM,rsquared_MLP-PM,Standard Error_MLP-PM,coef(b)_MLP-PM,coef(a)_Acu-MLP-PM,rsquared_Acu-MLP-PM,Standard Error_Acu-MLP-PM,coef(b)_Acu-MLP-PM,coef(a)_Pd-MLP-LM,rsquared_Pd-MLP-LM,Standard Error_Pd-MLP-LM,coef(b)_Pd-MLP-LM,coef(a)_Acu-Pd-MLP-LM,rsquared_Acu-Pd-MLP-LM,Standard Error_Acu-Pd-MLP-LM,coef(b)_Acu-Pd-MLP-LM,coef(a)_6am-MLP-LM,rsquared_6am-MLP-LM,Standard Error_6am-MLP-LM,coef(b)_6am-MLP-LM,coef(a)_Acu-6am-MLP-LM,rsquared_Acu-6am-MLP-LM,Standard Error_Acu-6am-MLP-LM,coef(b)_Acu-6am-MLP-LM
# 0,1.0,0.5785366421348257,0.3317848775240583,0.07433284941999714,0.023944053144725964,1.6708257727838738,0.9840059925682538,0.019285505431068724,-0.029319577394962874,0.6875082657678977,0.19976086320992306,0.12458125435326027,0.016516656300486533,1.358423154091092,0.9649055187901252,0.023454823992409914,-0.1607137662638552,-0.00025829422073386663,0.0001374690236494169,0.0019943551388658964,0.002349588834119262,0.11760342644202175,0.8354486442217129,0.00472531661376009,-0.021543543231872412,0.3603889116088532,0.20217285297901652,0.0648163352678497,0.029111884414240882,1.605381322448285,0.9839400763866464,0.0185688797262241,0.1817060149514628,0.385595073036268,0.2142431878001111,0.06685626339181851,0.02679280525334336,0.945058555173346,0.9964044959849576,0.003664503546241572,0.3650079530707189,0.6011191426705131,0.3720016545712075,0.070711074852455,0.01827464653893611,1.3910947430542413,0.9815101542243084,0.017286060946825086,0.04374884285326218
# 0,2.0,0.5700014679194878,0.4886142228534434,0.05279433320011552,0.01915843540647168,1.3254237831941058,0.9837093831463428,0.01544223660610161,-0.06015851921350261,0.6795293260219342,0.3137808231893304,0.09098012201953372,0.016048594975184752,1.3118662478623084,0.9757566584456904,0.018721262013580136,0.0024584208637453697,-0.002848460829983234,0.009551784343639569,0.002626055915278095,0.010297382671041263,0.21749023405187304,0.8491092704560737,0.008300597079522512,0.1102921856606263,0.383259646832818,0.21220096156128446,0.0668570567211512,0.026473525808082883,1.437781422991738,0.9834992743759968,0.016860771797320918,0.09532016352398992,0.3683002551647814,0.22795166874660297,0.06136531929206784,0.02557333454494147,1.0119689821600406,0.995050805196784,0.004606872856820903,0.3361396152275233,0.538944140344485,0.4590498001744544,0.052967878394451565,0.020578680034625027,1.381433841917426,0.985375128726194,0.01523685741677229,-0.06889852316313215
# 0,3.0,0.4505193961737048,0.4426898109710213,0.04576487877015166,0.01605597732167131,0.9575062882684818,0.9804115405645366,0.012253429466463659,0.18891713570498628,0.6630873386686476,0.38061281882164144,0.07658262015960729,0.011455499953121031,1.0598608680505974,0.9726015000423148,0.016105153474346785,0.11671055002563495,0.0024861125059326785,0.027388894012404963,0.0013412916696891298,-0.0020635647940567626,0.01699242202125268,0.3478987429117329,0.0021062332246567085,-0.01338676388780053,0.2680717482787616,0.2156868906579521,0.046281137081810766,0.023503000869004496,1.0719984829447318,0.9779746324737087,0.014565052094137044,0.2584491136242456,0.40016902346009003,0.2789220526094004,0.05825231941158871,0.021739791657065004,1.13974905703058,0.9892825139052898,0.0076575513571160185,-0.4504244844171567,0.4084883695395304,0.5240942995795862,0.03524159080970453,0.016649172209092185,0.9236298921791702,0.9736153678036013,0.01376574995009149,0.28901004261140284
# 0,4.0,0.4599956239999149,0.3252220808915629,0.0599879766923139,0.021674227676897924,1.1926401061533451,0.9772690881755768,0.016467620218138784,0.1901432317698916,0.4392516352312537,0.24623718324220045,0.06957833136766407,0.015693886372973403,0.8926497887700047,0.9834135619644608,0.01049565773614763,0.4180200574220141,0.0005015480083237105,0.0003291273638478253,0.002502528996464499,0.0043861857410478905,0.14333740073658674,0.8505218677900608,0.005440335694600387,0.07458580024486129,0.3349068821905499,0.17336167199525274,0.06621027571370786,0.02874801303494848,1.3726885231685495,0.98179696089624,0.01692205875699145,0.023710492250273205,0.37522235902359946,0.11643760617024213,0.09357953373432464,0.02831386799455284,1.023270576783763,0.9971038168228848,0.003559817134809875,0.02349624482465301,0.5142457620918317,0.2327655924466281,0.08452699927101358,0.02437641538453629,1.3779033152913969,0.9662419421468896,0.02331764116056216,0.14270135270886508
# 0,5.0,0.5853044925366626,0.4207858094277459,0.062171450371693325,0.023423315670821992,1.4390341218197564,0.9909378257718492,0.012459028457018646,-0.18748382297192495,0.8824279131649273,0.4034524313177124,0.0971461723193997,0.016485851466856563,1.4457767791991512,0.984842966502783,0.01623846379149681,-0.08175258273757091,0.0005871146662208103,0.000552307885028358,0.0022611658976767514,0.0040689223721926,0.1473045239721888,0.851520825484325,0.0055689241773928845,0.04938304576630324,0.2466934353540668,0.2406044087043474,0.03967892602888107,0.027229486198071192,1.2116179301510008,0.9910242958178442,0.01043945657850936,0.08372685995965423,0.3866625916841444,0.3332589788667801,0.04951535844483757,0.02229623051409884,1.056182069035883,0.9955095391689052,0.004578844683298338,-0.054166888747438934,0.6173192493706271,0.40360475034762255,0.06793895116921338,0.01923389644141307,1.2621288911090771,0.9815417805423592,0.01566983053520389,-0.23521072436680898
# 0,6.0,0.4298567644754648,0.5119053490594664,0.03800152667271569,0.01800729583693699,0.9795956120025764,0.9951306340782614,0.006203875490658957,0.10071158427371094,0.8045983375753806,0.547570899715485,0.0662146825376085,0.014157701821396631,1.2560337625508948,0.9909410871119012,0.010872652855272849,0.16356789168961305,-0.0006976593108274048,0.0009238114390028863,0.002077165571601255,0.006847979970744668,0.1554666057073536,0.8207571771579105,0.0065776497506481344,0.11972139033754688,0.3548397935746049,0.21038071321541665,0.06223839180881587,0.027282978189313814,1.2289280298713747,0.9902318693744684,0.011050547979537972,0.2580376178031435,0.4590344571852279,0.1130011050095454,0.1164355403205206,0.03038085633463535,0.9893595690315726,0.992370315610714,0.005599702322046133,0.26868918629206684,0.4462055484655663,0.4909158674782482,0.04113829579661449,0.016313553978237694,0.9489507069582842,0.9946271820118282,0.006314437055159005,0.070264191882739
# 0,7.0,0.4749739333654247,0.3496865704392617,0.05864240397860961,0.023715426559572005,1.1947518920037323,0.9918554439938474,0.009801833694754332,0.02273893237673437,0.8565182808762797,0.5536203885693302,0.06963103623585015,0.01064681811718352,1.1770455555590575,0.9902991828403852,0.010547130162245172,0.2738305799863208,0.0007865718868167683,0.0017975697995873394,0.0016781274237282838,0.0024237436076679137,0.1411313424212043,0.9018829929539218,0.0042144470764483785,-0.05982690803074706,0.3143842375597527,0.25273131173615937,0.048942901816238914,0.03007240883544878,1.2796534353472198,0.9856729207445928,0.013967699064314552,-0.02197494187130228,0.3733739251081424,0.32335460921942405,0.048899575913624566,0.025981873663556983,1.0294656993879632,0.9900074131804888,0.006676148717827839,-0.03822283000089509,0.3437818834749629,0.2268403191628944,0.0574615819201014,0.022302574743574558,0.9907710550294088,0.9915304256579454,0.008290317523912079,0.10115338471154303
# 0,8.0,0.478616164047445,0.4662275616761239,0.04636460090554035,0.018071857753451052,1.0437471363773776,0.990709296047384,0.00915095821089264,0.15666892595533966,0.6262573271898271,0.3214693793781593,0.08237355789300828,0.015862062476239,1.1038624231110838,0.985371781564613,0.012176730444146557,0.124676900134464,-0.002140800538679595,0.011614092751942251,0.0017879975411871309,0.00800207046635943,0.12351718704989133,0.8199167903491236,0.005240819453740349,0.061717840291329235,0.2896519208033342,0.2824658883690964,0.04179600154174516,0.02425555864523384,1.0817652236221185,0.9848034975428728,0.012166064980145476,0.1002979831296868,0.3364678636986212,0.2949806992393709,0.04709419478581992,0.023336867727641642,1.0491484473412993,0.9918155881191368,0.006151904641541011,0.08021758250542947,0.4761264789775794,0.5188846562149353,0.04150798115829255,0.017624204039710746,1.031938479821194,0.9892074921966988,0.009758686742084828,0.14962966587790513
# 0,9.0,0.6120214113522476,0.3928503346889768,0.06888442208534368,0.019662850695231496,1.5691794625004003,0.9755935443972688,0.022470389346101127,-0.04130902184354045,0.695353106958234,0.2801815208479665,0.10090605694824324,0.014608492608664815,1.3176074427715236,0.9426719118524534,0.02941775792415223,0.2331465885716831,-2.098363481716165e-05,2.855481231023305e-06,0.0011242438724293603,0.0012106819536894095,0.06797888835058583,0.8250431490578836,0.002834139927143976,-0.02408891807504084,0.3101601026982575,0.1973236516703014,0.056635227163214924,0.024190759553313915,1.430266105710264,0.9771078896304999,0.019820225293995773,-0.27655048637026763,0.30923856821381,0.2086788148376396,0.05451938066176209,0.020502816845832602,1.051405452579046,0.9948519745092109,0.004882089252432355,0.04276929964098503,0.5292343915892774,0.2607848137547554,0.08067007421928643,0.01926867226987684,1.5205846966814085,0.9727150630834692,0.02305681724624414,-0.12823356338166692
# 0,10.0,0.4428248008211189,0.3233166560455685,0.0580003600708636,0.021454373320384253,1.0921786698135776,0.9894569596714587,0.01020700329295571,0.3155911073991662,0.6421707464836138,0.24226253664581301,0.10282219060967668,0.019264367905588137,1.2105692826641352,0.980409391305094,0.015492801913534053,0.4303554312365757,-0.0014899690504829428,0.0049336876286657505,0.0019157441995293386,0.0057746722144300525,0.13971258782076704,0.7834930397159814,0.0066492702038257155,0.03980336467157925,0.29184554993082457,0.14013674657241304,0.06545033770224852,0.028185939471583862,1.2133005601902638,0.981616527267118,0.01503250401744683,0.3866751898928621,0.3232518468093268,0.15153095140855255,0.06925136907430904,0.025520765206509644,1.106678037007924,0.9956698353990164,0.0047109684658905426,-0.5523449018362622,0.4387009031538875,0.3269112914977176,0.05699146757811209,0.02063132319592475,1.0678176853585046,0.9912151987681156,0.009101211128668685,0.24003351843391826

# %%
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]

#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
#resultadoDatos= pd.concat(datostotal)

# %%
datos1=pd.read_csv('prueba.csv',decimal=",", encoding='utf-8',sep=u',')

# %%
datos1
# Out:
#    Unnamed: 0 Pruebas     coef(a)_6am-MLP    rsquared_6am-MLP  \
# 0           0     1.0  0.5785366421348257  0.3317848775240583
# 1           0     2.0  0.5700014679194878  0.4886142228534434
# 2           0     3.0  0.4505193961737048  0.4426898109710213
# 3           0     4.0  0.4599956239999149  0.3252220808915629
# 4           0     5.0  0.5853044925366626  0.4207858094277459
# 5           0     6.0  0.4298567644754648  0.5119053490594664
# 6           0     7.0  0.4749739333654247  0.3496865704392617
# 7           0     8.0   0.478616164047445  0.4662275616761239
# 8           0     9.0  0.6120214113522476  0.3928503346889768
# 9           0    10.0  0.4428248008211189  0.3233166560455685
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0    0.07433284941999714  0.023944053144725964  1.6708257727838738
# 1    0.05279433320011552   0.01915843540647168  1.3254237831941058
# 2    0.04576487877015166   0.01605597732167131  0.9575062882684818
# 3     0.0599879766923139  0.021674227676897924  1.1926401061533451
# 4   0.062171450371693325  0.023423315670821992  1.4390341218197564
# 5    0.03800152667271569   0.01800729583693699  0.9795956120025764
# 6    0.05864240397860961  0.023715426559572005  1.1947518920037323
# 7    0.04636460090554035  0.018071857753451052  1.0437471363773776
# 8    0.06888442208534368  0.019662850695231496  1.5691794625004003
# 9     0.0580003600708636  0.021454373320384253  1.0921786698135776
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP    coef(b)_Acu-6am-MLP  ...  \
# 0   0.9840059925682538       0.019285505431068724  -0.029319577394962874  ...
# 1   0.9837093831463428        0.01544223660610161   -0.06015851921350261  ...
# 2   0.9804115405645366       0.012253429466463659    0.18891713570498628  ...
# 3   0.9772690881755768       0.016467620218138784     0.1901432317698916  ...
# 4   0.9909378257718492       0.012459028457018646   -0.18748382297192495  ...
# 5   0.9951306340782614       0.006203875490658957    0.10071158427371094  ...
# 6   0.9918554439938474       0.009801833694754332    0.02273893237673437  ...
# 7    0.990709296047384        0.00915095821089264    0.15666892595533966  ...
# 8   0.9755935443972688       0.022470389346101127   -0.04130902184354045  ...
# 9   0.9894569596714587        0.01020700329295571     0.3155911073991662  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  coef(a)_6am-MLP-LM  \
# 0         0.003664503546241572     0.3650079530707189  0.6011191426705131
# 1         0.004606872856820903     0.3361396152275233   0.538944140344485
# 2        0.0076575513571160185    -0.4504244844171567  0.4084883695395304
# 3         0.003559817134809875    0.02349624482465301  0.5142457620918317
# 4         0.004578844683298338  -0.054166888747438934  0.6173192493706271
# 5         0.005599702322046133    0.26868918629206684  0.4462055484655663
# 6         0.006676148717827839   -0.03822283000089509  0.3437818834749629
# 7         0.006151904641541011    0.08021758250542947  0.4761264789775794
# 8         0.004882089252432355    0.04276929964098503  0.5292343915892774
# 9        0.0047109684658905426    -0.5523449018362622  0.4387009031538875
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0   0.3720016545712075         0.070711074852455   0.01827464653893611
# 1   0.4590498001744544      0.052967878394451565  0.020578680034625027
# 2   0.5240942995795862       0.03524159080970453  0.016649172209092185
# 3   0.2327655924466281       0.08452699927101358   0.02437641538453629
# 4  0.40360475034762255       0.06793895116921338   0.01923389644141307
# 5   0.4909158674782482       0.04113829579661449  0.016313553978237694
# 6   0.2268403191628944        0.0574615819201014  0.022302574743574558
# 7   0.5188846562149353       0.04150798115829255  0.017624204039710746
# 8   0.2607848137547554       0.08067007421928643   0.01926867226987684
# 9   0.3269112914977176       0.05699146757811209   0.02063132319592475
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     1.3910947430542413      0.9815101542243084
# 1      1.381433841917426       0.985375128726194
# 2     0.9236298921791702      0.9736153678036013
# 3     1.3779033152913969      0.9662419421468896
# 4     1.2621288911090771      0.9815417805423592
# 5     0.9489507069582842      0.9946271820118282
# 6     0.9907710550294088      0.9915304256579454
# 7      1.031938479821194      0.9892074921966988
# 8     1.5205846966814085      0.9727150630834692
# 9     1.0678176853585046      0.9912151987681156
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0          0.017286060946825086    0.04374884285326218
# 1           0.01523685741677229   -0.06889852316313215
# 2           0.01376574995009149    0.28901004261140284
# 3           0.02331764116056216    0.14270135270886508
# 4           0.01566983053520389   -0.23521072436680898
# 5          0.006314437055159005      0.070264191882739
# 6          0.008290317523912079    0.10115338471154303
# 7          0.009758686742084828    0.14962966587790513
# 8           0.02305681724624414   -0.12823356338166692
# 9          0.009101211128668685    0.24003351843391826
#
# [10 rows x 50 columns]

# %%
pwd
# Out:
# '/root/notebooks/resultados-31-01'

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
#3cp -r /root/notebooks/prueba.csv /root/notebooks/resultados-modelos-tesis

# %%
#cd resultados-modelos-tesis

# %%
# !git config user.email "rodrigo.montenegro@alumnos.uv.cl"

# !git config user.name "Rodrigomontenegrofarias"

# %%
# !git add .

# %%
# !git commit -m "a"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date
