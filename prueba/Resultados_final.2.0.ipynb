# %%
! rm -rf resultados-31-01 resultados-modelos-tesis

# %%
# !git clone git@github.com:Rodrigomontenegrofarias/resultados-31-01.git
# Out:
# Cloning into 'resultados-31-01'...
# remote: Enumerating objects: 679, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 679 (delta 68), reused 87 (delta 58), pack-reused 581
# Receiving objects: 100% (679/679), 112.74 MiB | 17.02 MiB/s, done.
# Resolving deltas: 100% (464/464), done.

# %%
cd resultados-31-01/
# Out:
# /root/notebooks/resultados-31-01

# %%
#cargamos librerias
import pandas as pd
import numpy as np
#graficas
import matplotlib.pylab as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,9)
plt.style.use('fast')
#ver redes neuronales

#sklear para ver modelos machine learning
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

import matplotlib.pyplot as plt
# plt.xkcd()
# plt.style.use('ggplot')
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (20, 8)

# %% [markdown]
# # Ingreso de bases de datos y coneccion a drive.

# %%
# !git config user.email "rodrigo.montenegro@alumnos.uv.cl"

# !git config user.name "Rodrigomontenegrofarias"

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
# solo el primer se encuentra en kl/h se debe cambiar a m/S

##Imprlementar desde github:

datos1=pd.read_csv('Prueba1.0.csv',decimal=",", encoding='utf-8',sep=u',')
datos2=pd.read_csv('Prueba2.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos3=pd.read_csv('Prueba3.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos4=pd.read_csv('Prueba4.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos5=pd.read_csv('Prueba5.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos6=pd.read_csv('Prueba6.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos7=pd.read_csv('Prueba7.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
datos8=pd.read_csv('Prueba8.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos9=pd.read_csv('Prueba9.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
datos10=pd.read_csv('Prueba10.0.csv',decimal=",",sep=u',', encoding='utf-8',dayfirst=True)

#datos11=pd.read_csv('/content/Rodrigomontenegrofarias/resultados/Prueba11.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos12=pd.read_csv('/content/Rodrigomontenegrofarias/resultados/Prueba12.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#datos13=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba13.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos14=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba14.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos15=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba15.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos16=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba16.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos17=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba17.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos18=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba18.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#datos19=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba19.0.csv',decimal=",",sep=u',', encoding='utf-8',  dayfirst=True)
#datos20=pd.read_csv('/content/Rodrigomontenegrofarias/Prueba20.0.csv',decimal=",",sep=u',', encoding='utf-8', dayfirst=True)
#Fecha
#datos1 = datos1.rename(columns={'Gust(km/h)':'Gust(m/s)'})
#datos1 = datos1.rename(columns={'Wind Speed(km/h)':'Wind Speed(m/s)'})


#df.columns
#Gust(km/h)
 
datos1
# Out:
#    Unnamed: 0 Pruebas     coef(a)_6am-MLP    rsquared_6am-MLP  \
# 0           0     1.0  0.4432812248563913  0.7094187739462607
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0   0.025685135492488822  0.013410438331940347  0.9431735635366079
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP   coef(b)_Acu-6am-MLP  ...  \
# 0   0.9937667589692936       0.006762798220113023  -0.07457834554857073  ...
#
#   Standard Error_Acu-Pd-MLP-LM coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0          0.00534486252973774  -0.14633500902708607  0.38003661309523196
#
#   rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.5712390889897778       0.02980877749086863  0.012863396944668114
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8647427551709324      0.9940554657153992
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0          0.006054253838700897   0.018505850002333325
#
# [1 rows x 50 columns]

# %%
print(datos1)
# Out:
#    Unnamed: 0 Pruebas     coef(a)_6am-MLP    rsquared_6am-MLP  \
# 0           0     1.0  0.4432812248563913  0.7094187739462607
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0   0.025685135492488822  0.013410438331940347  0.9431735635366079
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP   coef(b)_Acu-6am-MLP  ...  \
# 0   0.9937667589692936       0.006762798220113023  -0.07457834554857073  ...
#
#   Standard Error_Acu-Pd-MLP-LM coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0          0.00534486252973774  -0.14633500902708607  0.38003661309523196
#
#   rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0  0.5712390889897778       0.02980877749086863  0.012863396944668114
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8647427551709324      0.9940554657153992
#
#   Standard Error_Acu-6am-MLP-LM coef(b)_Acu-6am-MLP-LM
# 0          0.006054253838700897   0.018505850002333325
#
# [1 rows x 50 columns]

# %%
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,]
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
resultadoDatos= pd.concat(datostotal)

# %%
resultadoDatos
# Out:
#    Unnamed: 0 Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP  \
# 0           0     1.0   0.4432812248563913   0.7094187739462607
# 0           0     2.0   0.4796048953037074   0.3767219956238136
# 0           0     3.0   0.5779978775092328   0.5673712500240331
# 0           0     4.0   0.5124766097966704  0.32714563431623156
# 0           0     5.0  0.37677647783209284  0.39500765793964954
# 0           0     6.0   0.4056549634055106  0.24453613271512464
# 0           0     7.0   0.4985458546083713   0.3213389878354521
# 0           0     8.0   0.6383595307776139  0.36400090204745517
# 0           0     9.0  0.45710078512416674   0.3366993566300981
# 0           0    10.0   0.6308980037422067   0.3073365548822473
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0   0.025685135492488822  0.013410438331940347  0.9431735635366079
# 0   0.055851402323780615   0.02219021509260631  1.1757870494723308
# 0    0.04569517803951782  0.017014323206766678  1.1822034203538028
# 0    0.06654020142200127  0.022682639103001518  1.4236314575794808
# 0     0.0422158977487618  0.016903227729005897  0.9023266328630691
# 0    0.06455237294029988  0.023892280037442218  0.9468903560738214
# 0    0.06559487664857445  0.020533888284280717   1.102542588514258
# 0    0.07639456655522439   0.02146188463880798   1.461703022995117
# 0   0.058085283650014474  0.023877756604428063  1.2154192911392951
# 0    0.08574982620675535  0.021927273413652002  1.4068996791192998
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP   coef(b)_Acu-6am-MLP  ...  \
# 0   0.9937667589692936       0.006762798220113023  -0.07457834554857073  ...
# 0   0.9887835930781638       0.011337701235570059   0.30705407440828103  ...
# 0   0.9627361612696028       0.021057288550826714   -0.3598496962257913  ...
# 0    0.982898705822142        0.01700112918754081  0.029803666644996202  ...
# 0   0.9517958361415106         0.0183846022142025   0.05310802643106517  ...
# 0   0.9690865144597713        0.01531131475949692  -0.02957999596856096  ...
# 0   0.9796292543407621       0.014394217077834595   -0.0351149779132269  ...
# 0   0.9639418112791618       0.025595037870797394   -0.1399946430791032  ...
# 0   0.9835204297195952       0.014243852176187441  0.024622604344777158  ...
# 0   0.9791067611669716       0.018606773749191115  -0.19720421931968796  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0          0.00534486252973774   -0.14633500902708607  0.38003661309523196
# 0         0.004364301791335106   0.050600909283776266  0.40661661054084414
# 0         0.008697498946732708   -0.40978312364479125  0.46520369482753915
# 0         0.005414867777083633    -0.4805747374229224    0.522890261868388
# 0         0.007595050590423981   -0.22692384952497302   0.3356280692406337
# 0         0.004914123098970001    0.04517218536734509  0.30071555597224153
# 0         0.005625640653076002      0.312471046311489  0.44702338747327325
# 0        0.0035651224318606887    0.05230267053016455   0.6076133471824169
# 0         0.003183666010900769  -0.046893012745726576    0.395940522564466
# 0         0.003465053448107869    -0.1185177154895865  0.42708308581103394
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0   0.5712390889897778       0.02980877749086863  0.012863396944668114
# 0  0.36345981853720544       0.04871805425105309  0.021195067107157413
# 0  0.40292692227183746       0.05127005940515562   0.01554253256901424
# 0  0.34108629750019503        0.0657980082105963  0.019454605786726142
# 0   0.4455831110553683      0.033894733324367536  0.016172735652636154
# 0  0.21688580258179002       0.05173363676918476  0.022786816411985843
# 0  0.24458282731759196       0.07112639432733614   0.02409314600017903
# 0  0.32990083776910106       0.07840165235277201   0.02058681634649062
# 0  0.36760091507129267        0.0470172618922965  0.022158333871956707
# 0  0.23624859922842356       0.06952224985137608  0.019698859130720885
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8647427551709324      0.9940554657153992
# 0     1.0991359775293064      0.9867165066726061
# 0     1.0040802624108878      0.9574461245233723
# 0     1.2464186144927614      0.9897289028415114
# 0     0.8221797337621323      0.9612276609129506
# 0     0.8262739372727427      0.9689339052327589
# 0      1.246839762550044      0.9826424494994898
# 0     1.3802212046822215      0.9557030971549371
# 0      1.094841230309672      0.9843519934587098
# 0     1.0762850876766263       0.976150007131363
#
#   Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0          0.006054253838700897    0.018505850002333325
# 0          0.011545997567497128      0.2727195988040358
# 0           0.01916465041481412     -0.3005814344891554
# 0          0.011495670423349282     0.19790201329908402
# 0          0.014949777340902831  0.00019870795558294546
# 0          0.013394928291697942     0.00636134238439668
# 0          0.015002968045813638    -0.22558664355655766
# 0           0.02690258216464932    -0.15690750209398377
# 0           0.01249756847390436    0.022480052295110103
# 0          0.015231169587142303    -0.04180014497177754
#
# [10 rows x 50 columns]

# %%
#resultadoDatos['Pruebas'] = resultadoDatos['Pruebas'].astype('float')
#resultadoDatos = resultadoDatos.set_index('Pruebas')

# %%
resultadoDatos
# Out:
#    Unnamed: 0 Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP  \
# 0           0     1.0   0.4432812248563913   0.7094187739462607
# 0           0     2.0   0.4796048953037074   0.3767219956238136
# 0           0     3.0   0.5779978775092328   0.5673712500240331
# 0           0     4.0   0.5124766097966704  0.32714563431623156
# 0           0     5.0  0.37677647783209284  0.39500765793964954
# 0           0     6.0   0.4056549634055106  0.24453613271512464
# 0           0     7.0   0.4985458546083713   0.3213389878354521
# 0           0     8.0   0.6383595307776139  0.36400090204745517
# 0           0     9.0  0.45710078512416674   0.3366993566300981
# 0           0    10.0   0.6308980037422067   0.3073365548822473
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0   0.025685135492488822  0.013410438331940347  0.9431735635366079
# 0   0.055851402323780615   0.02219021509260631  1.1757870494723308
# 0    0.04569517803951782  0.017014323206766678  1.1822034203538028
# 0    0.06654020142200127  0.022682639103001518  1.4236314575794808
# 0     0.0422158977487618  0.016903227729005897  0.9023266328630691
# 0    0.06455237294029988  0.023892280037442218  0.9468903560738214
# 0    0.06559487664857445  0.020533888284280717   1.102542588514258
# 0    0.07639456655522439   0.02146188463880798   1.461703022995117
# 0   0.058085283650014474  0.023877756604428063  1.2154192911392951
# 0    0.08574982620675535  0.021927273413652002  1.4068996791192998
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP   coef(b)_Acu-6am-MLP  ...  \
# 0   0.9937667589692936       0.006762798220113023  -0.07457834554857073  ...
# 0   0.9887835930781638       0.011337701235570059   0.30705407440828103  ...
# 0   0.9627361612696028       0.021057288550826714   -0.3598496962257913  ...
# 0    0.982898705822142        0.01700112918754081  0.029803666644996202  ...
# 0   0.9517958361415106         0.0183846022142025   0.05310802643106517  ...
# 0   0.9690865144597713        0.01531131475949692  -0.02957999596856096  ...
# 0   0.9796292543407621       0.014394217077834595   -0.0351149779132269  ...
# 0   0.9639418112791618       0.025595037870797394   -0.1399946430791032  ...
# 0   0.9835204297195952       0.014243852176187441  0.024622604344777158  ...
# 0   0.9791067611669716       0.018606773749191115  -0.19720421931968796  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0          0.00534486252973774   -0.14633500902708607  0.38003661309523196
# 0         0.004364301791335106   0.050600909283776266  0.40661661054084414
# 0         0.008697498946732708   -0.40978312364479125  0.46520369482753915
# 0         0.005414867777083633    -0.4805747374229224    0.522890261868388
# 0         0.007595050590423981   -0.22692384952497302   0.3356280692406337
# 0         0.004914123098970001    0.04517218536734509  0.30071555597224153
# 0         0.005625640653076002      0.312471046311489  0.44702338747327325
# 0        0.0035651224318606887    0.05230267053016455   0.6076133471824169
# 0         0.003183666010900769  -0.046893012745726576    0.395940522564466
# 0         0.003465053448107869    -0.1185177154895865  0.42708308581103394
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0   0.5712390889897778       0.02980877749086863  0.012863396944668114
# 0  0.36345981853720544       0.04871805425105309  0.021195067107157413
# 0  0.40292692227183746       0.05127005940515562   0.01554253256901424
# 0  0.34108629750019503        0.0657980082105963  0.019454605786726142
# 0   0.4455831110553683      0.033894733324367536  0.016172735652636154
# 0  0.21688580258179002       0.05173363676918476  0.022786816411985843
# 0  0.24458282731759196       0.07112639432733614   0.02409314600017903
# 0  0.32990083776910106       0.07840165235277201   0.02058681634649062
# 0  0.36760091507129267        0.0470172618922965  0.022158333871956707
# 0  0.23624859922842356       0.06952224985137608  0.019698859130720885
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8647427551709324      0.9940554657153992
# 0     1.0991359775293064      0.9867165066726061
# 0     1.0040802624108878      0.9574461245233723
# 0     1.2464186144927614      0.9897289028415114
# 0     0.8221797337621323      0.9612276609129506
# 0     0.8262739372727427      0.9689339052327589
# 0      1.246839762550044      0.9826424494994898
# 0     1.3802212046822215      0.9557030971549371
# 0      1.094841230309672      0.9843519934587098
# 0     1.0762850876766263       0.976150007131363
#
#   Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0          0.006054253838700897    0.018505850002333325
# 0          0.011545997567497128      0.2727195988040358
# 0           0.01916465041481412     -0.3005814344891554
# 0          0.011495670423349282     0.19790201329908402
# 0          0.014949777340902831  0.00019870795558294546
# 0          0.013394928291697942     0.00636134238439668
# 0          0.015002968045813638    -0.22558664355655766
# 0           0.02690258216464932    -0.15690750209398377
# 0           0.01249756847390436    0.022480052295110103
# 0          0.015231169587142303    -0.04180014497177754
#
# [10 rows x 50 columns]

# %%
resultadoDatos = resultadoDatos.drop(['Unnamed: 0'], axis=1)

# %%
resultadoDatos
# Out:
#   Pruebas      coef(a)_6am-MLP     rsquared_6am-MLP Standard Error_6am-MLP  \
# 0     1.0   0.4432812248563913   0.7094187739462607   0.025685135492488822
# 0     2.0   0.4796048953037074   0.3767219956238136   0.055851402323780615
# 0     3.0   0.5779978775092328   0.5673712500240331    0.04569517803951782
# 0     4.0   0.5124766097966704  0.32714563431623156    0.06654020142200127
# 0     5.0  0.37677647783209284  0.39500765793964954     0.0422158977487618
# 0     6.0   0.4056549634055106  0.24453613271512464    0.06455237294029988
# 0     7.0   0.4985458546083713   0.3213389878354521    0.06559487664857445
# 0     8.0   0.6383595307776139  0.36400090204745517    0.07639456655522439
# 0     9.0  0.45710078512416674   0.3366993566300981   0.058085283650014474
# 0    10.0   0.6308980037422067   0.3073365548822473    0.08574982620675535
#
#         coef(b)_6am-MLP coef(a)_Acu-6am-MLP rsquared_Acu-6am-MLP  \
# 0  0.013410438331940347  0.9431735635366079   0.9937667589692936
# 0   0.02219021509260631  1.1757870494723308   0.9887835930781638
# 0  0.017014323206766678  1.1822034203538028   0.9627361612696028
# 0  0.022682639103001518  1.4236314575794808    0.982898705822142
# 0  0.016903227729005897  0.9023266328630691   0.9517958361415106
# 0  0.023892280037442218  0.9468903560738214   0.9690865144597713
# 0  0.020533888284280717   1.102542588514258   0.9796292543407621
# 0   0.02146188463880798   1.461703022995117   0.9639418112791618
# 0  0.023877756604428063  1.2154192911392951   0.9835204297195952
# 0  0.021927273413652002  1.4068996791192998   0.9791067611669716
#
#   Standard Error_Acu-6am-MLP   coef(b)_Acu-6am-MLP  coef(a)_6am-Beysens  ...  \
# 0       0.006762798220113023  -0.07457834554857073   0.6364201438537339  ...
# 0       0.011337701235570059   0.30705407440828103   0.7261431022109126  ...
# 0       0.021057288550826714   -0.3598496962257913   0.7546341181687521  ...
# 0        0.01700112918754081  0.029803666644996202  0.49665699397271323  ...
# 0         0.0183846022142025   0.05310802643106517    0.509791234944508  ...
# 0        0.01531131475949692  -0.02957999596856096   0.4048204281085085  ...
# 0       0.014394217077834595   -0.0351149779132269   0.6977640732778709  ...
# 0       0.025595037870797394   -0.1399946430791032   0.5900369406789487  ...
# 0       0.014243852176187441  0.024622604344777158   0.5303075335139501  ...
# 0       0.018606773749191115  -0.19720421931968796   0.6463179247177431  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0          0.00534486252973774   -0.14633500902708607  0.38003661309523196
# 0         0.004364301791335106   0.050600909283776266  0.40661661054084414
# 0         0.008697498946732708   -0.40978312364479125  0.46520369482753915
# 0         0.005414867777083633    -0.4805747374229224    0.522890261868388
# 0         0.007595050590423981   -0.22692384952497302   0.3356280692406337
# 0         0.004914123098970001    0.04517218536734509  0.30071555597224153
# 0         0.005625640653076002      0.312471046311489  0.44702338747327325
# 0        0.0035651224318606887    0.05230267053016455   0.6076133471824169
# 0         0.003183666010900769  -0.046893012745726576    0.395940522564466
# 0         0.003465053448107869    -0.1185177154895865  0.42708308581103394
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0   0.5712390889897778       0.02980877749086863  0.012863396944668114
# 0  0.36345981853720544       0.04871805425105309  0.021195067107157413
# 0  0.40292692227183746       0.05127005940515562   0.01554253256901424
# 0  0.34108629750019503        0.0657980082105963  0.019454605786726142
# 0   0.4455831110553683      0.033894733324367536  0.016172735652636154
# 0  0.21688580258179002       0.05173363676918476  0.022786816411985843
# 0  0.24458282731759196       0.07112639432733614   0.02409314600017903
# 0  0.32990083776910106       0.07840165235277201   0.02058681634649062
# 0  0.36760091507129267        0.0470172618922965  0.022158333871956707
# 0  0.23624859922842356       0.06952224985137608  0.019698859130720885
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8647427551709324      0.9940554657153992
# 0     1.0991359775293064      0.9867165066726061
# 0     1.0040802624108878      0.9574461245233723
# 0     1.2464186144927614      0.9897289028415114
# 0     0.8221797337621323      0.9612276609129506
# 0     0.8262739372727427      0.9689339052327589
# 0      1.246839762550044      0.9826424494994898
# 0     1.3802212046822215      0.9557030971549371
# 0      1.094841230309672      0.9843519934587098
# 0     1.0762850876766263       0.976150007131363
#
#   Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0          0.006054253838700897    0.018505850002333325
# 0          0.011545997567497128      0.2727195988040358
# 0           0.01916465041481412     -0.3005814344891554
# 0          0.011495670423349282     0.19790201329908402
# 0          0.014949777340902831  0.00019870795558294546
# 0          0.013394928291697942     0.00636134238439668
# 0          0.015002968045813638    -0.22558664355655766
# 0           0.02690258216464932    -0.15690750209398377
# 0           0.01249756847390436    0.022480052295110103
# 0          0.015231169587142303    -0.04180014497177754
#
# [10 rows x 49 columns]

# %%
resultadoDatos=resultadoDatos.astype(float)

# %%
resultadoDatos
# Out:
#    Pruebas  coef(a)_6am-MLP  rsquared_6am-MLP  Standard Error_6am-MLP  \
# 0      1.0         0.443281          0.709419                0.025685
# 0      2.0         0.479605          0.376722                0.055851
# 0      3.0         0.577998          0.567371                0.045695
# 0      4.0         0.512477          0.327146                0.066540
# 0      5.0         0.376776          0.395008                0.042216
# 0      6.0         0.405655          0.244536                0.064552
# 0      7.0         0.498546          0.321339                0.065595
# 0      8.0         0.638360          0.364001                0.076395
# 0      9.0         0.457101          0.336699                0.058085
# 0     10.0         0.630898          0.307337                0.085750
#
#    coef(b)_6am-MLP  coef(a)_Acu-6am-MLP  rsquared_Acu-6am-MLP  \
# 0         0.013410             0.943174              0.993767
# 0         0.022190             1.175787              0.988784
# 0         0.017014             1.182203              0.962736
# 0         0.022683             1.423631              0.982899
# 0         0.016903             0.902327              0.951796
# 0         0.023892             0.946890              0.969087
# 0         0.020534             1.102543              0.979629
# 0         0.021462             1.461703              0.963942
# 0         0.023878             1.215419              0.983520
# 0         0.021927             1.406900              0.979107
#
#    Standard Error_Acu-6am-MLP  coef(b)_Acu-6am-MLP  coef(a)_6am-Beysens  ...  \
# 0                    0.006763            -0.074578             0.636420  ...
# 0                    0.011338             0.307054             0.726143  ...
# 0                    0.021057            -0.359850             0.754634  ...
# 0                    0.017001             0.029804             0.496657  ...
# 0                    0.018385             0.053108             0.509791  ...
# 0                    0.015311            -0.029580             0.404820  ...
# 0                    0.014394            -0.035115             0.697764  ...
# 0                    0.025595            -0.139995             0.590037  ...
# 0                    0.014244             0.024623             0.530308  ...
# 0                    0.018607            -0.197204             0.646318  ...
#
#    Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  coef(a)_6am-MLP-LM  \
# 0                      0.005345              -0.146335            0.380037
# 0                      0.004364               0.050601            0.406617
# 0                      0.008697              -0.409783            0.465204
# 0                      0.005415              -0.480575            0.522890
# 0                      0.007595              -0.226924            0.335628
# 0                      0.004914               0.045172            0.300716
# 0                      0.005626               0.312471            0.447023
# 0                      0.003565               0.052303            0.607613
# 0                      0.003184              -0.046893            0.395941
# 0                      0.003465              -0.118518            0.427083
#
#    rsquared_6am-MLP-LM  Standard Error_6am-MLP-LM  coef(b)_6am-MLP-LM  \
# 0             0.571239                   0.029809            0.012863
# 0             0.363460                   0.048718            0.021195
# 0             0.402927                   0.051270            0.015543
# 0             0.341086                   0.065798            0.019455
# 0             0.445583                   0.033895            0.016173
# 0             0.216886                   0.051734            0.022787
# 0             0.244583                   0.071126            0.024093
# 0             0.329901                   0.078402            0.020587
# 0             0.367601                   0.047017            0.022158
# 0             0.236249                   0.069522            0.019699
#
#    coef(a)_Acu-6am-MLP-LM  rsquared_Acu-6am-MLP-LM  \
# 0                0.864743                 0.994055
# 0                1.099136                 0.986717
# 0                1.004080                 0.957446
# 0                1.246419                 0.989729
# 0                0.822180                 0.961228
# 0                0.826274                 0.968934
# 0                1.246840                 0.982642
# 0                1.380221                 0.955703
# 0                1.094841                 0.984352
# 0                1.076285                 0.976150
#
#    Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0                       0.006054                0.018506
# 0                       0.011546                0.272720
# 0                       0.019165               -0.300581
# 0                       0.011496                0.197902
# 0                       0.014950                0.000199
# 0                       0.013395                0.006361
# 0                       0.015003               -0.225587
# 0                       0.026903               -0.156908
# 0                       0.012498                0.022480
# 0                       0.015231               -0.041800
#
# [10 rows x 49 columns]

# %%
#mean_df = df['R-cuadrado-Modelo-Beysens(6am)'].mean()
#print(mean_df)

# %% [markdown]
# # Resultados de Pruebas a modelo test ADAMAX

# %%
import matplotlib.pyplot as plt

# %%
#Graficos

# %% [markdown]
# ## grafico 1, modelo R cuadrado

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo MLP 6AM")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
mean_df1 = resultadoDatos['rsquared_6am-Beysens'].mean()
print(mean_df1)
# Out:
# 0.29244593542429337

# %%
mean_df = resultadoDatos['rsquared_6am-MLP'].mean()
print(mean_df)
# Out:
# 0.39495772459603656

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-MLP']))
# Out:
# 0.1185201284463143
# 0.13889220624088375

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP 6AM")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df111 = resultadoDatos['coef(a)_6am-Beysens'].mean()
print(mean_df111)
# Out:
# 0.599289249344764

# %%
mean_df = resultadoDatos['coef(a)_6am-MLP'].mean()
print(mean_df)
# Out:
# 0.5020696222955964

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-MLP']))
# Out:
# 0.11289970870542579
# 0.08946421241965524

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP 6AM")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df1145 = resultadoDatos['coef(b)_6am-Beysens'].mean()
print(mean_df1145)
# Out:
# 0.016451859090389057

# %%
mean_df1245 = resultadoDatos['coef(b)_6am-MLP'].mean()
print(mean_df1245)
# Out:
# 0.02038939264419317

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-MLP']))
# Out:
# 0.006272383342311185
# 0.0034757458378794725

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP 6AM")
plt.ylabel('Resultados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df114 = resultadoDatos['Standard Error_6am-Beysens'].mean()
print(mean_df114)
# Out:
# 0.08677970892023582

# %%
mean_df124 = resultadoDatos['Standard Error_6am-MLP'].mean()
print(mean_df124)
# Out:
# 0.058636474102741885

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-MLP']))
# Out:
# 0.015328831499490927
# 0.017407959431057236

# %% [markdown]
# ## grafico 2

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo Acumulado MLP 6AM")
plt.ylabel('Resultados acumulados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-Beysens'].mean()
print(mean_df11)
# Out:
# 0.9657159821405491

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-MLP'].mean()
print(mean_df11)
# Out:
# 0.9755265826246975

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-MLP']))
# Out:
# 0.01779991722393813
# 0.013160447294204977

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP 6AM")
plt.ylabel('Resultados acumulados de pendient')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11112 = resultadoDatos['coef(a)_Acu-6am-Beysens'].mean()
print(mean_df11112)
# Out:
# 1.1395461890114151

# %%
mean_df11111 = resultadoDatos['coef(a)_Acu-6am-MLP'].mean()
print(mean_df11111)
# Out:
# 1.1760577061647082

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-MLP']))
# Out:
# 0.16811899789297863
# 0.20678681307979394

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-6am-MLP']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP 6AM")
plt.ylabel('Resultados acumulados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df63 = resultadoDatos['coef(b)_Acu-6am-Beysens'].mean()
print(mean_df63)
# Out:
# -0.019366422629672732

# %%
mean_df64= resultadoDatos['coef(b)_Acu-6am-MLP'].mean()
print(mean_df64)
# Out:
# -0.04217335062258215

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-MLP']))
# Out:
# 0.30469576560436157
# 0.17526521452017219

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas1= resultadoDatos['Pruebas']
resultados1={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-6am-MLP']}
ax.plot(pruebas1,resultados1['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas1,resultados1['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP 6AM")
plt.ylabel('Resultados acumulados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-Beysens'].mean()
print(mean_df6)
# Out:
# 0.01881591743569416

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-MLP'].mean()
print(mean_df6)
# Out:
# 0.01626947150417606

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Out:
# 0.004920959699414697
# 0.013789008896173831

# %% [markdown]
# ## grafico 3

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo MLP PD")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['rsquared_Beysens-PM'].mean()
print(mean_df6)
# Out:
# 0.01168525470928521

# %%
mean_df7 = resultadoDatos['rsquared_MLP-PM'].mean()
print(mean_df7)
# Out:
# 0.22605610065470919

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_MLP-PM']))
# Out:
# 0.013789008896173831
# 0.06907905862644069

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP PD")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df77 = resultadoDatos['coef(a)_Beysens-PM'].mean()
print(mean_df77)
# Out:
# 0.0001181077949232623

# %%
mean_df78 = resultadoDatos['coef(a)_MLP-PM'].mean()
print(mean_df78)
# Out:
# 0.3234408725198751

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_MLP-PM']))
# Out:
# 0.001894406028228172
# 0.05469290630107446

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP PD")
plt.ylabel('Resultados de coeficiente')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df781 = resultadoDatos['coef(b)_Beysens-PM'].mean()
print(mean_df781)
# Out:
# 0.0030875044820432777

# %%
mean_df786 = resultadoDatos['coef(b)_MLP-PM'].mean()
print(mean_df786)
# Out:
# 0.025578648910375035

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_MLP-PM']))
# Out:
# 0.0031127179808615136
# 0.005112399797604203

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP PD")
plt.ylabel('Resultados Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864 = resultadoDatos['Standard Error_Beysens-PM'].mean()
print(mean_df7864)
# Out:
# 0.001698237156104248

# %%
mean_df7865 = resultadoDatos['Standard Error_MLP-PM'].mean()
print(mean_df7865)
# Out:
# 0.0572418344756498

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_MLP-PM']))
# Out:
# 0.0009501341356210723
# 0.01989265381393091

# %% [markdown]
# ## grafico 4

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo Acumulado MLP PD")
plt.ylabel('Resultados acumulados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df8 = resultadoDatos['rsquared_Acu-Beysens-PM'].mean()
print(mean_df8)
# Out:
# 0.6849703534010084

# %%
mean_df9 = resultadoDatos['rsquared_Acu-MLP-PM'].mean()
print(mean_df9)
# Out:
# 0.9730629461889724

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-MLP-PM']))
# Out:
# 0.2738837007489728
# 0.018104866527324067

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP PD")
plt.ylabel('Resultados acumulados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df78649 = resultadoDatos['coef(a)_Acu-Beysens-PM'].mean()
print(mean_df78649)
# Out:
# 0.12646828330665855

# %%
mean_df78648 = resultadoDatos['coef(a)_Acu-MLP-PM'].mean()
print(mean_df78648)
# Out:
# 1.2372758896670775

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-MLP-PM']))
# Out:
# 0.11505685925936796
# 0.357117712027257

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP PD")
plt.ylabel('Resultados acumulados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Beysens-PM'].mean()
print(mean_df786489)
# Out:
# -0.01975776118806245

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-MLP-PM'].mean()
print(mean_df786489)
# Out:
# 0.004293151677179058

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-MLP-PM']))
# Out:
# 0.09186528536488638
# 0.3186829425258297

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo de Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Acumulado Modelo MLP PD")
plt.ylabel('Resultados acumulados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864899 = resultadoDatos['Standard Error_Acu-Beysens-PM'].mean()
print(mean_df7864899)
# Out:
# 0.004756842560898059

# %%
mean_df78648999 = resultadoDatos['Standard Error_Acu-MLP-PM'].mean()
print(mean_df78648999)
# Out:
# 0.017604247127368855

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-MLP-PM']))
# Out:
# 0.003126094987162935
# 0.007208468336167633

# %%
#########################################################################################

# %% [markdown]
# # Resultados de Pruebas LM

# %%
import matplotlib.pyplot as plt

# %%
#Graficos

# %%
resultadoDatos
# Out:
#    Pruebas  coef(a)_6am-MLP  rsquared_6am-MLP  Standard Error_6am-MLP  \
# 0      1.0         0.443281          0.709419                0.025685
# 0      2.0         0.479605          0.376722                0.055851
# 0      3.0         0.577998          0.567371                0.045695
# 0      4.0         0.512477          0.327146                0.066540
# 0      5.0         0.376776          0.395008                0.042216
# 0      6.0         0.405655          0.244536                0.064552
# 0      7.0         0.498546          0.321339                0.065595
# 0      8.0         0.638360          0.364001                0.076395
# 0      9.0         0.457101          0.336699                0.058085
# 0     10.0         0.630898          0.307337                0.085750
#
#    coef(b)_6am-MLP  coef(a)_Acu-6am-MLP  rsquared_Acu-6am-MLP  \
# 0         0.013410             0.943174              0.993767
# 0         0.022190             1.175787              0.988784
# 0         0.017014             1.182203              0.962736
# 0         0.022683             1.423631              0.982899
# 0         0.016903             0.902327              0.951796
# 0         0.023892             0.946890              0.969087
# 0         0.020534             1.102543              0.979629
# 0         0.021462             1.461703              0.963942
# 0         0.023878             1.215419              0.983520
# 0         0.021927             1.406900              0.979107
#
#    Standard Error_Acu-6am-MLP  coef(b)_Acu-6am-MLP  coef(a)_6am-Beysens  ...  \
# 0                    0.006763            -0.074578             0.636420  ...
# 0                    0.011338             0.307054             0.726143  ...
# 0                    0.021057            -0.359850             0.754634  ...
# 0                    0.017001             0.029804             0.496657  ...
# 0                    0.018385             0.053108             0.509791  ...
# 0                    0.015311            -0.029580             0.404820  ...
# 0                    0.014394            -0.035115             0.697764  ...
# 0                    0.025595            -0.139995             0.590037  ...
# 0                    0.014244             0.024623             0.530308  ...
# 0                    0.018607            -0.197204             0.646318  ...
#
#    Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM  coef(a)_6am-MLP-LM  \
# 0                      0.005345              -0.146335            0.380037
# 0                      0.004364               0.050601            0.406617
# 0                      0.008697              -0.409783            0.465204
# 0                      0.005415              -0.480575            0.522890
# 0                      0.007595              -0.226924            0.335628
# 0                      0.004914               0.045172            0.300716
# 0                      0.005626               0.312471            0.447023
# 0                      0.003565               0.052303            0.607613
# 0                      0.003184              -0.046893            0.395941
# 0                      0.003465              -0.118518            0.427083
#
#    rsquared_6am-MLP-LM  Standard Error_6am-MLP-LM  coef(b)_6am-MLP-LM  \
# 0             0.571239                   0.029809            0.012863
# 0             0.363460                   0.048718            0.021195
# 0             0.402927                   0.051270            0.015543
# 0             0.341086                   0.065798            0.019455
# 0             0.445583                   0.033895            0.016173
# 0             0.216886                   0.051734            0.022787
# 0             0.244583                   0.071126            0.024093
# 0             0.329901                   0.078402            0.020587
# 0             0.367601                   0.047017            0.022158
# 0             0.236249                   0.069522            0.019699
#
#    coef(a)_Acu-6am-MLP-LM  rsquared_Acu-6am-MLP-LM  \
# 0                0.864743                 0.994055
# 0                1.099136                 0.986717
# 0                1.004080                 0.957446
# 0                1.246419                 0.989729
# 0                0.822180                 0.961228
# 0                0.826274                 0.968934
# 0                1.246840                 0.982642
# 0                1.380221                 0.955703
# 0                1.094841                 0.984352
# 0                1.076285                 0.976150
#
#    Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0                       0.006054                0.018506
# 0                       0.011546                0.272720
# 0                       0.019165               -0.300581
# 0                       0.011496                0.197902
# 0                       0.014950                0.000199
# 0                       0.013395                0.006361
# 0                       0.015003               -0.225587
# 0                       0.026903               -0.156908
# 0                       0.012498                0.022480
# 0                       0.015231               -0.041800
#
# [10 rows x 49 columns]

# %% [markdown]
# ## grafico 1, modelo R cuadrado

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo MLP LM 6AM")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:1377: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:237: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:239: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
mean_df1 = resultadoDatos['rsquared_6am-Beysens'].mean()
print(mean_df1)
# Out:
# 0.29244593542429337

# %%
mean_df = resultadoDatos['rsquared_6am-MLP-LM'].mean()
print(mean_df)
# Out:
# 0.3519514220322584

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_6am-MLP-LM']))
# Out:
# 0.1185201284463143
# 0.10728569574682462

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP LM 6AM")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df111 = resultadoDatos['coef(a)_6am-Beysens'].mean()
print(mean_df111)
# Out:
# 0.599289249344764

# %%
mean_df = resultadoDatos['coef(a)_6am-MLP-LM'].mean()
print(mean_df)
# Out:
# 0.4288751148576068

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_6am-MLP-LM']))
# Out:
# 0.11289970870542579
# 0.08914641647938157

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP LM 6AM")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df1145 = resultadoDatos['coef(b)_6am-Beysens'].mean()
print(mean_df1145)
# Out:
# 0.016451859090389057

# %%
mean_df1245 = resultadoDatos['coef(b)_6am-MLP-LM'].mean()
print(mean_df1245)
# Out:
# 0.019455230982153515

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_6am-MLP-LM']))
# Out:
# 0.006272383342311185
# 0.0035562091724833313

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP LM 6AM")
plt.ylabel('Resultados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df114 = resultadoDatos['Standard Error_6am-Beysens'].mean()
print(mean_df114)
# Out:
# 0.08677970892023582

# %%
mean_df124 = resultadoDatos['Standard Error_6am-MLP-LM'].mean()
print(mean_df124)
# Out:
# 0.054729082787500674

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_6am-MLP-LM']))
# Out:
# 0.015328831499490927
# 0.01613228369926474

# %% [markdown]
# ## grafico 2

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="R² del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="R² del Modelo Acumulado MLP LM 6AM")
plt.ylabel('Resultados acumulado de R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-Beysens'].mean()
print(mean_df11)
# Out:
# 0.9657159821405491

# %%
mean_df11 = resultadoDatos['rsquared_Acu-6am-MLP-LM'].mean()
print(mean_df11)
# Out:
# 0.9756956113143097

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-6am-MLP-LM']))
# Out:
# 0.01779991722393813
# 0.014010560683004864

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP LM 6AM")
plt.ylabel('Resultados acumulados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df11112 = resultadoDatos['coef(a)_Acu-6am-Beysens'].mean()
print(mean_df11112)
# Out:
# 1.1395461890114151

# %%
mean_df11111 = resultadoDatos['coef(a)_Acu-6am-MLP-LM'].mean()
print(mean_df11111)
# Out:
# 1.066101856585733

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-6am-MLP-LM']))
# Out:
# 0.16811899789297863
# 0.1906945755734877

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens 6AM")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP LM 6AM")
plt.ylabel('Resultados acumulados de coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df63 = resultadoDatos['coef(b)_Acu-6am-Beysens'].mean()
print(mean_df63)
# Out:
# -0.019366422629672732

# %%
mean_df64= resultadoDatos['coef(b)_Acu-6am-MLP-LM'].mean()
print(mean_df64)
# Out:
# -0.020670816037093146

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-6am-MLP-LM']))
# Out:
# 0.30469576560436157
# 0.17567724013854416

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas1= resultadoDatos['Pruebas']
resultados1={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-6am-MLP-LM']}
ax.plot(pruebas1,resultados1['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens 6AM")
ax.plot(pruebas1,resultados1['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP LM 6AM")
plt.ylabel('Resultados acumulados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-Beysens'].mean()
print(mean_df6)
# Out:
# 0.01881591743569416

# %%
mean_df6 = resultadoDatos['Standard Error_Acu-6am-MLP-LM'].mean()
print(mean_df6)
# Out:
# 0.01462395661484718

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-Beysens']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-6am-MLP-LM']))
# Out:
# 0.004920959699414697
# 0.005484654462842276

# %% [markdown]
# ## grafico 3

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo MLP LM PD")
plt.ylabel('Resultados R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df6 = resultadoDatos['rsquared_Beysens-PM'].mean()
print(mean_df6)
# Out:
# 0.01168525470928521

# %%
mean_df7 = resultadoDatos['rsquared_Pd-MLP-LM'].mean()
print(mean_df7)
# Out:
# 0.21383973357425176

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Pd-MLP-LM']))
# Out:
# 0.013789008896173831
# 0.06364736224018022

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo MLP LM PD")
plt.ylabel('Resultados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df77 = resultadoDatos['coef(a)_Beysens-PM'].mean()
print(mean_df77)
# Out:
# 0.0001181077949232623

# %%
mean_df78 = resultadoDatos['coef(a)_Pd-MLP-LM'].mean()
print(mean_df78)
# Out:
# 0.347648211010069

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Pd-MLP-LM']))
# Out:
# 0.001894406028228172
# 0.07909621060618403

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo MLP LM PD")
plt.ylabel('Resultados de coeficientes')
plt.xlabel('cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df781 = resultadoDatos['coef(b)_Beysens-PM'].mean()
print(mean_df781)
# Out:
# 0.0030875044820432777

# %%
mean_df786 = resultadoDatos['coef(b)_Pd-MLP-LM'].mean()
print(mean_df786)
# Out:
# 0.02390064350227028

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Pd-MLP-LM']))
# Out:
# 0.0031127179808615136
# 0.005921480270079569

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Modelo MLP LM PD")
plt.ylabel('Resultados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864 = resultadoDatos['Standard Error_Beysens-PM'].mean()
print(mean_df7864)
# Out:
# 0.001698237156104248

# %%
mean_df7865 = resultadoDatos['Standard Error_Pd-MLP-LM'].mean()
print(mean_df7865)
# Out:
# 0.06330873105672218

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Pd-MLP-LM']))
# Out:
# 0.0009501341356210723
# 0.020462676657539303

# %% [markdown]
# ## grafico 4

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="R² del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="R² del Modelo Acumulado MLP LM PD")
plt.ylabel('Resultados acumulados de R²')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df8 = resultadoDatos['rsquared_Acu-Beysens-PM'].mean()
print(mean_df8)
# Out:
# 0.6849703534010084

# %%
mean_df9 = resultadoDatos['rsquared_Acu-Pd-MLP-LM'].mean()
print(mean_df9)
# Out:
# 0.993287251473259

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['rsquared_Acu-Pd-MLP-LM']))
# Out:
# 0.2738837007489728
# 0.0047179530669457835

# %% [markdown]
# ## m

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Pendiente del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Pendiente del Modelo Acumulado MLP LM PD")
plt.ylabel('Resultados acumulados de pendientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df78649 = resultadoDatos['coef(a)_Acu-Beysens-PM'].mean()
print(mean_df78649)
# Out:
# 0.12646828330665855

# %%
mean_df78648 = resultadoDatos['coef(a)_Acu-Pd-MLP-LM'].mean()
print(mean_df78648)
# Out:
# 1.0313134139499502

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(a)_Acu-Pd-MLP-LM']))
# Out:
# 0.11505685925936796
# 0.04923478483998052

# %% [markdown]
# ## coef

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(b)_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['coef(b)_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Coef del Modelo Acumulado Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Coef del Modelo Acumulado MLP LM PD")
plt.ylabel('Resultados acumulados de Coeficientes')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Beysens-PM'].mean()
print(mean_df786489)
# Out:
# -0.01975776118806245

# %%
mean_df786489 = resultadoDatos['coef(b)_Acu-Pd-MLP-LM'].mean()
print(mean_df786489)
# Out:
# -0.09684806363623108

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['coef(b)_Acu-Pd-MLP-LM']))
# Out:
# 0.09186528536488638
# 0.23551534197031274

# %% [markdown]
# ## error

# %%
fig, ax = plt.subplots(figsize=(8,6))   
#rsquared

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['Standard Error_Acu-Beysens-PM'],'Modelo RNA(6am)':resultadoDatos['Standard Error_Acu-Pd-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="SE del Modelo de Beysens PD")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="SE del Acumulado Modelo MLP LM PD")
plt.ylabel('Resultados acumulados de Standard Error')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
mean_df7864899 = resultadoDatos['Standard Error_Acu-Beysens-PM'].mean()
print(mean_df7864899)
# Out:
# 0.004756842560898059

# %%
mean_df78648999 = resultadoDatos['Standard Error_Acu-Pd-MLP-LM'].mean()
print(mean_df78648999)
# Out:
# 0.005217018727822849

# %%
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Beysens-PM']))
# Import statistics Library
import statistics

# Calculate the standard deviation from a sample of data
print(statistics.stdev(resultadoDatos['Standard Error_Acu-Pd-MLP-LM']))
# Out:
# 0.003126094987162935
# 0.0017870763577746498

# %% [markdown]
# ## Combinacion entre los modelos para tabla de conclusion.

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'], marker = 'o',label="Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['rsquared_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['rsquared_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-Acumulado-MLP(6am)")
#ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="M Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="M Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="M Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
#cambiar 
#resultado6=pd.merge(df5, df6, on='Pruebas', suffixes=('_Beysens-PM', '_Acu-Beysens-PM'))

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="Modelo-MLP-6am-LM")
plt.ylabel('Resultado R cuadrado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %% [markdown]
# resultados con modelo LM

# %%
fig, ax = plt.subplots(figsize=(8,6)) 

pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['coef(a)_Acu-6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['coef(a)_Acu-6am-MLP'],'Modelo Beysens(PM)':resultadoDatos['coef(a)_Acu-Beysens-PM'],'Modelo RNA(PM)':resultadoDatos['coef(a)_Acu-MLP-PM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="M Modelo-Acumulado-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = 'o',label="M Modelo-Acumulado-MLP(6am)")
ax.plot(pruebas,resultados['Modelo Beysens(PM)'], marker ='^',label="Modelo-Acumulado-Beysens(PM)")
ax.plot(pruebas,resultados['Modelo RNA(PM)'],c='red', marker = 'o',label="M Modelo-Acumulado-MLP(PM)")
plt.ylabel('Resultados R cuadrado acumulado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))   


pruebas= resultadoDatos['Pruebas']
resultados={'Modelo Beysens(6am)':resultadoDatos['rsquared_6am-Beysens'],'Modelo RNA(6am)':resultadoDatos['rsquared_6am-MLP'],'Modelo RNA(6am)1':resultadoDatos['rsquared_6am-MLP-LM']}
ax.plot(pruebas,resultados['Modelo Beysens(6am)'], marker ='^',label="Modelo-Beysens(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)'], marker = '^',label="Modelo-MLP(6am)")
ax.plot(pruebas,resultados['Modelo RNA(6am)1'],c='red', marker = 'o',label="Modelo-MLP-6am-LM")
plt.ylabel('Resultado R cuadrado')
plt.xlabel('Cantidad de Pruebas')
legend = ax.legend(loc="best")  
plt.show()

# %%
# Connect to the MySQL database
import pandas as pd
from sqlalchemy import create_engine
# Read CSV file into a DataFrame
#df = pd.read_csv("Prueba"+str(n)+".csv")
# Create a database engine
engine = create_engine('mysql+pymysql://root:sSeCr4t100114@24.199.124.40/demo')

# %%
from sqlalchemy import create_engine
import pandas as pd

# Create engine
engine = create_engine('mysql+pymysql://root:sSeCr4t100114@24.199.124.40/demo')

# Get data from engine
data = pd.read_sql_table('prueba', engine)

# Export data to CSV
data.to_csv('prueba.csv', index=False)

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
pwd
# Out:
# '/root/notebooks/resultados-31-01'

# %%
cat prueba.csv
# Out:
# Unnamed: 0,Pruebas,coef(a)_6am-MLP,rsquared_6am-MLP,Standard Error_6am-MLP,coef(b)_6am-MLP,coef(a)_Acu-6am-MLP,rsquared_Acu-6am-MLP,Standard Error_Acu-6am-MLP,coef(b)_Acu-6am-MLP,coef(a)_6am-Beysens,rsquared_6am-Beysens,Standard Error_6am-Beysens,coef(b)_6am-Beysens,coef(a)_Acu-6am-Beysens,rsquared_Acu-6am-Beysens,Standard Error_Acu-6am-Beysens,coef(b)_Acu-6am-Beysens,coef(a)_Beysens-PM,rsquared_Beysens-PM,Standard Error_Beysens-PM,coef(b)_Beysens-PM,coef(a)_Acu-Beysens-PM,rsquared_Acu-Beysens-PM,Standard Error_Acu-Beysens-PM,coef(b)_Acu-Beysens-PM,coef(a)_MLP-PM,rsquared_MLP-PM,Standard Error_MLP-PM,coef(b)_MLP-PM,coef(a)_Acu-MLP-PM,rsquared_Acu-MLP-PM,Standard Error_Acu-MLP-PM,coef(b)_Acu-MLP-PM,coef(a)_Pd-MLP-LM,rsquared_Pd-MLP-LM,Standard Error_Pd-MLP-LM,coef(b)_Pd-MLP-LM,coef(a)_Acu-Pd-MLP-LM,rsquared_Acu-Pd-MLP-LM,Standard Error_Acu-Pd-MLP-LM,coef(b)_Acu-Pd-MLP-LM,coef(a)_6am-MLP-LM,rsquared_6am-MLP-LM,Standard Error_6am-MLP-LM,coef(b)_6am-MLP-LM,coef(a)_Acu-6am-MLP-LM,rsquared_Acu-6am-MLP-LM,Standard Error_Acu-6am-MLP-LM,coef(b)_Acu-6am-MLP-LM
# 0,1.0,0.4432812248563913,0.7094187739462607,0.025685135492488825,0.013410438331940349,0.943173563536608,0.9937667589692936,0.006762798220113023,-0.07457834554857072,0.6364201438537339,0.4823339992953122,0.05969182886418875,0.005341655750246726,0.8879851180842045,0.9671532564948254,0.014815771877149863,-0.4511295497531208,0.0004894083914755267,0.02144158790307393,0.0002993342425800329,-0.0005809722191849857,0.002956356705836161,0.13592509423517085,0.0006748430712636179,-0.003521711633939308,0.34999312892128986,0.18059879566835849,0.0674948298217268,0.0211961281965767,1.0260181326970286,0.9718081543875374,0.01582146177255068,0.18065368376028604,0.3515833619192245,0.1574913962261365,0.07362192348893612,0.01647930267983075,1.016888004717445,0.993413297630694,0.0053448625297377395,-0.14633500902708607,0.380036613095232,0.5712390889897778,0.029808777490868632,0.012863396944668114,0.8647427551709324,0.9940554657153992,0.006054253838700897,0.018505850002333325
# 0,2.0,0.4796048953037074,0.3767219956238136,0.05585140232378062,0.02219021509260631,1.1757870494723308,0.9887835930781638,0.011337701235570059,0.30705407440828103,0.7261431022109126,0.35583068893531355,0.08845463923178383,0.018871058140871425,1.3100026418954378,0.9810539618499132,0.016481814120655653,0.4966678693828688,0.002848302525868657,0.012321137583423902,0.0023088125572072946,0.0012337774921215418,0.25206763558741396,0.8575759335203352,0.009300206052477486,-0.12384494897018547,0.3375050632131261,0.2734232559395249,0.04981078242758948,0.027577478640602743,1.3911480668716585,0.9831690254506452,0.01647911861208465,0.386277280364596,0.2819339003691925,0.17260483642426416,0.055885269055951085,0.02912541880273618,1.0711157600522734,0.9960313665661245,0.004364301791335106,0.050600909283776266,0.40661661054084414,0.36345981853720544,0.048718054251053085,0.021195067107157413,1.0991359775293064,0.986716506672606,0.011545997567497128,0.2727195988040358
# 0,3.0,0.5779978775092328,0.5673712500240331,0.045695178039517816,0.017014323206766678,1.1822034203538028,0.9627361612696028,0.021057288550826714,-0.3598496962257913,0.7546341181687521,0.4779802148143338,0.07139947901542089,0.007592442424789952,1.064825895150283,0.9877382134844874,0.010741245330136177,-0.2654404284658453,-0.0006186477652709282,0.0061508758808950246,0.0007119594863645082,0.002436172854316789,0.047206026306060175,0.8096264349479113,0.0020724235094680865,-0.01640191160776524,0.2631015534979044,0.22562961341533536,0.04412856945047625,0.02214541910355975,1.0822427986704493,0.955156992106014,0.02123023377537561,-0.5375655441517454,0.3400824035428603,0.267360982551066,0.050968312699031404,0.019215265184193808,1.0536913756048465,0.9839110026908008,0.008697498946732708,-0.4097831236447913,0.4652036948275392,0.4029269222718375,0.05127005940515562,0.01554253256901424,1.0040802624108878,0.9574461245233724,0.01916465041481412,-0.3005814344891554
# 0,4.0,0.5124766097966704,0.3271456343162316,0.06654020142200127,0.022682639103001518,1.4236314575794808,0.9828987058221421,0.01700112918754081,0.0298036666449962,0.4966569939727132,0.16257402661348586,0.10205264669339782,0.01812392126320075,1.2638054351526673,0.9701564912518122,0.02006801180113736,0.24264017081505904,-0.002485474212058871,0.04399007169893665,0.0010490186575370336,0.0052178647630862105,0.010088879902841632,0.27558583265605485,0.0014809079369911757,0.13449391985416329,0.3970535157738302,0.3207355486840324,0.052313650022073936,0.02703562266097067,1.3985264194963074,0.9899503114556591,0.012757346819763805,0.20782728443595672,0.5395302510855366,0.2643327742381695,0.08148939548013986,0.024922475411389942,1.1002342896855617,0.9942203802605096,0.005414867777083633,-0.4805747374229224,0.5228902618683879,0.34108629750019503,0.0657980082105963,0.019454605786726142,1.2464186144927614,0.9897289028415114,0.01149567042334928,0.197902013299084
# 0,5.0,0.3767764778320928,0.3950076579396496,0.0422158977487618,0.016903227729005897,0.9023266328630692,0.9517958361415106,0.0183846022142025,0.053108026431065165,0.509791234944508,0.26342284484074674,0.07717823699203613,0.01622602852876364,1.0012321351278817,0.9223707732202676,0.02629751602150685,0.14533514830388675,-0.001641075953402567,0.007305470917028156,0.0017319385246127655,0.00614238728057539,0.11117880862547123,0.6878128633320155,0.006781323394949361,0.07031709732034991,0.26323930554126906,0.2531641856065393,0.04093381843086186,0.02221770017395589,0.9911775369527492,0.9309303202723628,0.02444312165158924,0.1753274597509899,0.2743795438421596,0.25511592989465715,0.042447032137959625,0.020191983604979626,0.9831457702881684,0.9858791629543646,0.007595050590423981,-0.22692384952497305,0.3356280692406337,0.4455831110553683,0.033894733324367536,0.016172735652636154,0.8221797337621323,0.9612276609129506,0.014949777340902831,0.00019870795558294543
# 0,6.0,0.4056549634055106,0.24453613271512464,0.06455237294029988,0.023892280037442214,0.9468903560738214,0.9690865144597712,0.015311314759496918,-0.029579995968560962,0.4048204281085085,0.1556002161550768,0.08537907851868226,0.02561559010258431,1.0077423784485102,0.9630758891781502,0.017864644348857286,-0.1848126715950264,0.003516958482172697,0.02075588401291728,0.002187067534938989,-0.001674468869149913,0.11592962799316288,0.8258145481360262,0.004820356980831043,-0.046997683056297083,0.2833056073743533,0.16592259912535545,0.05750766222140655,0.026427741837012,1.0032995422132591,0.98000978829912,0.012973112649300218,0.0166934502482741,0.3237635860710006,0.17649484233101664,0.06331626416491208,0.02589929292077041,1.075518321230128,0.9950146328632392,0.004914123098970001,0.04517218536734509,0.30071555597224153,0.21688580258179,0.051733636769184764,0.022786816411985843,0.8262739372727427,0.9689339052327588,0.013394928291697942,0.006361342384396679
# 0,7.0,0.4985458546083713,0.3213389878354521,0.06559487664857445,0.020533888284280717,1.1025425885142581,0.979629254340762,0.014394217077834597,-0.0351149779132269,0.6977640732778709,0.2824231899009516,0.10069611376575922,0.017087805158199944,1.1176880920192245,0.9650918738504308,0.01924507675549889,0.028763986230811982,0.00040351078783806534,0.0013452129172594196,0.000995376571333083,0.0008583609690467363,0.029657695691524245,0.5881873422108193,0.002246722827360564,0.02254236112914336,0.3009971722799332,0.3118035074526022,0.04048538392638575,0.02164598070646428,0.985918292307084,0.9783198414465514,0.013287760908828218,0.06407823107296988,0.2952744095917056,0.28251663934366755,0.042601984763620364,0.01897521155434176,1.0252546718044258,0.992825943083972,0.0056256406530760025,0.31247104631148903,0.4470233874732733,0.244582827317592,0.07112639432733614,0.02409314600017903,1.2468397625500438,0.9826424494994898,0.015002968045813638,-0.2255866435565577
# 0,8.0,0.6383595307776139,0.3640009020474552,0.07639456655522439,0.021461884638807983,1.4617030229951171,0.9639418112791618,0.025595037870797397,-0.1399946430791032,0.5900369406789487,0.18637689636586965,0.11161302676725886,0.01932934928106857,1.4609822430152437,0.963271311999511,0.025828156929253568,-0.12960484484518606,-0.000986822691181274,0.0006625698869935358,0.0034697600473380585,0.007888468330588637,0.3323783769750438,0.9153746704103148,0.009149631191967609,-0.16006370355116722,0.3790157891169573,0.09314625203567363,0.10706887221427283,0.03847056779272348,2.138964398226696,0.9693949824453206,0.034408803629715934,-0.5699169818339909,0.3664862811457187,0.08898059951702998,0.10616805261459837,0.036839408640439435,1.0619592400782285,0.9973024387082424,0.003565122431860689,0.05230267053016455,0.6076133471824169,0.32990083776910106,0.07840165235277201,0.02058681634649062,1.3802212046822215,0.9557030971549372,0.02690258216464932,-0.15690750209398374
# 0,9.0,0.4571007851241667,0.3366993566300981,0.058085283650014474,0.023877756604428063,1.2154192911392951,0.9835204297195952,0.014243852176187441,0.02462260434477716,0.5303075335139501,0.2355167186688406,0.0865009757667699,0.02290506180564793,1.1594399927432284,0.9586125134761644,0.02181128941113701,0.2652559702537245,-0.0009686248020030684,0.002334072888126704,0.0018130552255297282,0.005041511478909128,0.11058710624663892,0.8281163542449363,0.004561379183236645,0.034089666686997575,0.26668218617652273,0.20866857499129754,0.04701806708414168,0.025596746921720388,1.053572803588707,0.9812460552728544,0.013186878017466692,0.18846829328654915,0.2968325111172638,0.26603226641442546,0.04463781032123719,0.024264431791130844,0.9696513572675742,0.9974194465679272,0.003183666010900769,-0.046893012745726576,0.395940522564466,0.3676009150712927,0.0470172618922965,0.02215833387195671,1.094841230309672,0.9843519934587098,0.012497568473904359,0.022480052295110103
# 0,10.0,0.6308980037422067,0.3073365548822473,0.08574982620675535,0.021927273413652,1.4068996791192998,0.9791067611669716,0.018606773749191115,-0.197204219319688,0.6463179247177431,0.3224005586530031,0.0848310635870605,0.013425678448517293,1.1217579584774715,0.9786355365999272,0.015005647761608943,-0.34133987662389986,0.0006235431857943849,0.0005456634041974828,0.002416048713600986,0.004311942740123243,0.2526323190325924,0.9256844603165,0.006480631460434995,-0.10819069805192433,0.3935154033035641,0.22746867362837264,0.06565670915756279,0.023473103070164425,1.301890905646836,0.9906439907536564,0.011454633437013502,-0.06891164016209482,0.4066158614160278,0.20746706880208488,0.07195126584083568,0.023093644432890026,0.9556753487708491,0.9968548434067156,0.003465053448107869,-0.1185177154895865,0.4270830858110339,0.2362485992284236,0.06952224985137608,0.019698859130720885,1.0762850876766263,0.9761500071313629,0.015231169587142303,-0.04180014497177754

# %%
#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos7,datos8,datos9,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]

#datostotal = [datos1,datos2,datos3,datos4,datos5,datos6,datos10,datos11,datos12,datos13,datos14,datos15,datos16,datos17,datos18,datos19,datos20, ]
#resultadoDatos= pd.concat(datostotal)

# %%
datos1=pd.read_csv('prueba.csv',decimal=",", encoding='utf-8',sep=u',')

# %%
datos1
# Out:
#    Unnamed: 0 Pruebas     coef(a)_6am-MLP     rsquared_6am-MLP  \
# 0           0     1.0  0.4432812248563913   0.7094187739462607
# 1           0     2.0  0.4796048953037074   0.3767219956238136
# 2           0     3.0  0.5779978775092328   0.5673712500240331
# 3           0     4.0  0.5124766097966704   0.3271456343162316
# 4           0     5.0  0.3767764778320928   0.3950076579396496
# 5           0     6.0  0.4056549634055106  0.24453613271512464
# 6           0     7.0  0.4985458546083713   0.3213389878354521
# 7           0     8.0  0.6383595307776139   0.3640009020474552
# 8           0     9.0  0.4571007851241667   0.3366993566300981
# 9           0    10.0  0.6308980037422067   0.3073365548822473
#
#   Standard Error_6am-MLP       coef(b)_6am-MLP coef(a)_Acu-6am-MLP  \
# 0   0.025685135492488825  0.013410438331940349   0.943173563536608
# 1    0.05585140232378062   0.02219021509260631  1.1757870494723308
# 2   0.045695178039517816  0.017014323206766678  1.1822034203538028
# 3    0.06654020142200127  0.022682639103001518  1.4236314575794808
# 4     0.0422158977487618  0.016903227729005897  0.9023266328630692
# 5    0.06455237294029988  0.023892280037442214  0.9468903560738214
# 6    0.06559487664857445  0.020533888284280717  1.1025425885142581
# 7    0.07639456655522439  0.021461884638807983  1.4617030229951171
# 8   0.058085283650014474  0.023877756604428063  1.2154192911392951
# 9    0.08574982620675535     0.021927273413652  1.4068996791192998
#
#   rsquared_Acu-6am-MLP Standard Error_Acu-6am-MLP    coef(b)_Acu-6am-MLP  ...  \
# 0   0.9937667589692936       0.006762798220113023   -0.07457834554857072  ...
# 1   0.9887835930781638       0.011337701235570059    0.30705407440828103  ...
# 2   0.9627361612696028       0.021057288550826714    -0.3598496962257913  ...
# 3   0.9828987058221421        0.01700112918754081     0.0298036666449962  ...
# 4   0.9517958361415106         0.0183846022142025   0.053108026431065165  ...
# 5   0.9690865144597712       0.015311314759496918  -0.029579995968560962  ...
# 6    0.979629254340762       0.014394217077834597    -0.0351149779132269  ...
# 7   0.9639418112791618       0.025595037870797397    -0.1399946430791032  ...
# 8   0.9835204297195952       0.014243852176187441    0.02462260434477716  ...
# 9   0.9791067611669716       0.018606773749191115     -0.197204219319688  ...
#
#   Standard Error_Acu-Pd-MLP-LM  coef(b)_Acu-Pd-MLP-LM   coef(a)_6am-MLP-LM  \
# 0        0.0053448625297377395   -0.14633500902708607    0.380036613095232
# 1         0.004364301791335106   0.050600909283776266  0.40661661054084414
# 2         0.008697498946732708    -0.4097831236447913   0.4652036948275392
# 3         0.005414867777083633    -0.4805747374229224   0.5228902618683879
# 4         0.007595050590423981   -0.22692384952497305   0.3356280692406337
# 5         0.004914123098970001    0.04517218536734509  0.30071555597224153
# 6        0.0056256406530760025    0.31247104631148903   0.4470233874732733
# 7         0.003565122431860689    0.05230267053016455   0.6076133471824169
# 8         0.003183666010900769  -0.046893012745726576    0.395940522564466
# 9         0.003465053448107869    -0.1185177154895865   0.4270830858110339
#
#    rsquared_6am-MLP-LM Standard Error_6am-MLP-LM    coef(b)_6am-MLP-LM  \
# 0   0.5712390889897778      0.029808777490868632  0.012863396944668114
# 1  0.36345981853720544      0.048718054251053085  0.021195067107157413
# 2   0.4029269222718375       0.05127005940515562   0.01554253256901424
# 3  0.34108629750019503        0.0657980082105963  0.019454605786726142
# 4   0.4455831110553683      0.033894733324367536  0.016172735652636154
# 5     0.21688580258179      0.051733636769184764  0.022786816411985843
# 6    0.244582827317592       0.07112639432733614   0.02409314600017903
# 7  0.32990083776910106       0.07840165235277201   0.02058681634649062
# 8   0.3676009150712927        0.0470172618922965   0.02215833387195671
# 9   0.2362485992284236       0.06952224985137608  0.019698859130720885
#
#   coef(a)_Acu-6am-MLP-LM rsquared_Acu-6am-MLP-LM  \
# 0     0.8647427551709324      0.9940554657153992
# 1     1.0991359775293064       0.986716506672606
# 2     1.0040802624108878      0.9574461245233724
# 3     1.2464186144927614      0.9897289028415114
# 4     0.8221797337621323      0.9612276609129506
# 5     0.8262739372727427      0.9689339052327588
# 6     1.2468397625500438      0.9826424494994898
# 7     1.3802212046822215      0.9557030971549372
# 8      1.094841230309672      0.9843519934587098
# 9     1.0762850876766263      0.9761500071313629
#
#   Standard Error_Acu-6am-MLP-LM  coef(b)_Acu-6am-MLP-LM
# 0          0.006054253838700897    0.018505850002333325
# 1          0.011545997567497128      0.2727195988040358
# 2           0.01916465041481412     -0.3005814344891554
# 3           0.01149567042334928       0.197902013299084
# 4          0.014949777340902831  0.00019870795558294543
# 5          0.013394928291697942    0.006361342384396679
# 6          0.015002968045813638     -0.2255866435565577
# 7           0.02690258216464932    -0.15690750209398374
# 8          0.012497568473904359    0.022480052295110103
# 9          0.015231169587142303    -0.04180014497177754
#
# [10 rows x 50 columns]

# %%
pwd
# Out:
# '/root/notebooks/resultados-31-01'

# %%
ls
# Out:
# prueba/         Prueba2.0.csv  Prueba5.0.csv  Prueba8.0.csv  README.md
# Prueba10.0.csv  Prueba3.0.csv  Prueba6.0.csv  Prueba9.0.csv
# Prueba1.0.csv   Prueba4.0.csv  Prueba7.0.csv  prueba.csv

# %%
#3cp -r /root/notebooks/prueba.csv /root/notebooks/resultados-modelos-tesis

# %%
#cd resultados-modelos-tesis

# %%
# !git config user.email "rodrigo.montenegro@alumnos.uv.cl"

# !git config user.name "Rodrigomontenegrofarias"

# %%
# !git add .

# %%
# !git commit -m "a"
# Out:
# [main 5487230] a
#  1 file changed, 1 insertion(+)

# %%
# !git push origin main
# Out:
# Counting objects: 3, done.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 787 bytes | 787.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:Rodrigomontenegrofarias/resultados-31-01.git
#    f0a5f04..5487230  main -> main
